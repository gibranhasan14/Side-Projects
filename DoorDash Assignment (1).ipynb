# %%
import datetime as dt
import pandas as pd
import numpy as np
pd.set_option('max_colwidth', 200)
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
import re
import matplotlib.pyplot as plt
# %matplotlib inline

plt.style.use('ggplot')
# Out:
# <style>.container { width:100% !important; }</style>

# %%
data= pd.read_excel('Sales_Ops_Sample_Data_(1).xlsx')

# %%
data.head(5)
# Out:
#   Customer placed order datetime Placed order with restaurant datetime  \
# 0                    14 20:27:45                           14 20:29:41
# 1                    07 20:16:28                           07 20:17:32
# 2                    13 19:35:09                           13 19:39:26
# 3                    22 19:47:53                           22 19:56:08
# 4                    03 19:01:52                           03 19:09:08
#
#   Driver at restaurant datetime Delivered to consumer datetime  Driver ID  \
# 0                   14 20:39:32                    14 20:52:03         86
# 1                   07 20:36:00                    07 20:49:02        325
# 2                   13 20:28:16                    13 20:52:44        200
# 3                   22 20:01:20                    22 20:18:01        154
# 4                   03 19:36:20                    03 19:45:26        332
#
#    Restaurant ID  Consumer ID  Is New Delivery Region  Is ASAP  Order total  \
# 0             12            5   False       Palo Alto     True        20.45
# 1             66            5   False       Palo Alto     True        40.62
# 2            124            5   False       Palo Alto     True        37.78
# 3              5           14   False       Palo Alto     True        39.66
# 4              9           14   False       Palo Alto     True        39.66
#
#    Amount of discount  Amount of tip  Refunded amount
# 0               20.45           3.07              0.0
# 1               40.62           3.73              0.0
# 2               37.78           1.89              0.0
# 3                0.00           1.98              0.0
# 4                0.00           5.95              0.0

# %%
data['Customer placed order datetime'].str[:3].head(5)
# Out:
# 0    14
# 1    07
# 2    13
# 3    22
# 4    03
# Name: Customer placed order datetime, dtype: object

# %%
pd.to_timedelta(data['Customer placed order datetime'].str[3:]).head(5)
# Out:
# 0   20:27:45
# 1   20:16:28
# 2   19:35:09
# 3   19:47:53
# 4   19:01:52
# Name: Customer placed order datetime, dtype: timedelta64[ns]

# %%
(pd.to_datetime(data['Delivered to consumer datetime'].str[3:]).dt.minute - pd.to_datetime(data['Customer placed order datetime'].str[3:]).dt.minute).head(10)
# Out:
# 0    25
# 1    33
# 2    17
# 3   -29
# 4    44
# 5   -25
# 6   -20
# 7     4
# 8   -31
# 9    46
# dtype: int64

# %%
data['Date1_day'] = data['Delivered to consumer datetime'].str.slice(start=0, stop=3)
data['Date2_day'] = data['Customer placed order datetime'].str.slice(start=0, stop=3)
data['Date1'] = pd.to_datetime(data['Delivered to consumer datetime'].str.slice(start=3))
data['Date2'] = pd.to_datetime(data['Customer placed order datetime'].str.slice(start=3))

data['Total_Delivery_Time(mins)'] = np.where(data['Date1_day'] == data['Date2_day'],
                            data['Date1'] - data['Date2'],
                            np.NaN)

data.drop(['Date1','Date2','Date1_day', 'Date2_day'], axis=1, inplace=True)
data['Total_Delivery_Time(mins)'] = data['Total_Delivery_Time(mins)'] / np.timedelta64(1,'m')

# %%
# def diff_func(x):
#     cust_time = pd.to_datetime(x['Delivered to consumer datetime'], format='%d %H:%M:%S')
#     del_time = pd.to_datetime(x['Customer placed order datetime'], format='%d %H:%M:%S')
#     if cust_time.day == del_time.day:
#         return del_time.minute - cust_time.minute
#     else:
#         return None

# data['Total_Delivery_Time(mins)'] = data.apply(diff_func, axis=1)
#data['Total_Delivery_Time(mins)'] = abs(data['Total_Delivery_Time(mins)'])

# %%
data['Total_after_disc'] = data['Order total'] - data['Amount of discount']

# %%
data[data['Amount of discount']>0]['Delivery Region'].value_counts()
# Out:
# Palo Alto        1443
# San Jose          841
# Mountain View     504
# Name: Delivery Region, dtype: int64

# %%
#Average Order Total
round(data['Total_after_disc'].mean(), 2)
# Out:
# 49.9

# %%
# Average Total Delivery Time in Mins
round(abs(data['Total_Delivery_Time(mins)'].mean()), 2)
# Out:
# 57.02

# %%
round(100*data['Delivery Region'].value_counts(normalize=True),2)
# Out:
# Palo Alto        63.24
# Mountain View    20.80
# San Jose         15.81
# None              0.14
# Name: Delivery Region, dtype: float64

# %%
#Avg delivery times for each City/Region
round(data.groupby('Delivery Region')['Total_Delivery_Time(mins)'].mean(),2)
# Out:
# Delivery Region
# Mountain View     56.00
# None             269.89
# Palo Alto         57.42
# San Jose          54.76
# Name: Total_Delivery_Time(mins), dtype: float64

# %%
round(data.groupby('Delivery Region')['Total_Delivery_Time(mins)'].mean(),2).idxmax(),\
round(data.groupby('Delivery Region')['Total_Delivery_Time(mins)'].mean(),2).max()
# Out:
# ('None', 269.89)

# %%
data.describe()
# Out:
#           Driver ID  Restaurant ID    Consumer ID   Order total  \
# count  18078.000000   18078.000000   18078.000000  18078.000000
# mean     222.448169     108.721263   32010.313475     51.261496
# std      105.219194      98.609766   42010.215766     50.599675
# min        7.000000       2.000000       5.000000      0.000000
# 25%      141.000000      23.000000    4243.500000     26.660000
# 50%      227.000000      77.000000   10972.000000     38.630000
# 75%      314.000000     186.000000   56857.000000     57.885000
# max      438.000000     409.000000  200449.000000   1604.130000
#
#        Amount of discount  Amount of tip  Refunded amount  \
# count        18078.000000   18078.000000     18078.000000
# mean             1.356706       3.492022         0.612091
# std              6.516667       3.700115         6.073104
# min              0.000000       0.000000         0.000000
# 25%              0.000000       1.400000         0.000000
# 50%              0.000000       2.550000         0.000000
# 75%              0.000000       4.460000         0.000000
# max            187.880000     120.300000       414.770000
#
#        Total_Delivery_Time(mins)  Total_after_disc
# count               16305.000000      18078.000000
# mean                   57.023757         49.904790
# std                    63.393334         50.765906
# min                     0.466667          0.000000
# 25%                    36.566667         25.550000
# 50%                    46.783333         37.480000
# 75%                    61.566667         56.565000
# max                  1209.966667       1604.130000

# %%
round(data.groupby(['Delivery Region']).agg({'Consumer ID': 'count','Total_Delivery_Time(mins)':'mean','Total_after_disc':'mean'
                                            ,'Amount of discount':'mean'}).sort_values(by='Consumer ID', ascending=False),2)
# Out:
#                  Consumer ID  Total_Delivery_Time(mins)  Total_after_disc  \
# Delivery Region
# Palo Alto              11433                      57.42             51.16
# Mountain View           3760                      56.00             51.02
# San Jose                2859                      54.76             41.83
# None                      26                     269.89            224.36
#
#                  Amount of discount
# Delivery Region
# Palo Alto                      1.32
# Mountain View                  1.05
# San Jose                       1.91
# None                           0.00

# %%
#Customers with the most orders
data.groupby('Consumer ID').agg({'Consumer ID': 'count'}).sort_values(by='Consumer ID', ascending=False)
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: 'Consumer ID' is both an index level and a column label.
# Defaulting to column, but this will raise an ambiguity error in a future version
#   """Entry point for launching an IPython kernel.
#              Consumer ID
# Consumer ID
# 514                   66
# 929                   50
# 11956                 47
# 2469                  43
# 4087                  39
# 2435                  37
# 22183                 36
# 8000                  35
# 6245                  33
# 13018                 27
# 14043                 27
# 4484                  25
# 8405                  25
# 2156                  24
# 10512                 24
# 3879                  23
# 1719                  22
# 7920                  22
# 2931                  22
# 27495                 22
# 78977                 22
# 79259                 22
# 14519                 22
# 1226                  22
# 8076                  22
# 1160                  22
# 1103                  22
# 10294                 21
# 7403                  21
# 5673                  21
# ...                  ...
# 3005                   1
# 35723                  1
# 35714                  1
# 35689                  1
# 33564                  1
# 33614                  1
# 33787                  1
# 33798                  1
# 34057                  1
# 3082                   1
# 3075                   1
# 34196                  1
# 34264                  1
# 3066                   1
# 3062                   1
# 3039                   1
# 3037                   1
# 34821                  1
# 34843                  1
# 3030                   1
# 35133                  1
# 3029                   1
# 35342                  1
# 35557                  1
# 3021                   1
# 3017                   1
# 3006                   1
# 35681                  1
# 35688                  1
# 200449                 1
#
# [6701 rows x 1 columns]

# %% [markdown]
# # FRAUD ANALYSIS

# %%
data.pivot_table('Consumer ID', index='Is New', columns='Delivery Region', aggfunc='count')
# Out:
# Delivery Region  Mountain View  None  Palo Alto  San Jose
# Is New
# False                     3040    23       9310      2193
# True                       720     3       2123       666

# %%
data[data['Is New']==True].groupby('Delivery Region')['Consumer ID'].count()
# Out:
# Delivery Region
# Mountain View     720
# None                3
# Palo Alto        2123
# San Jose          666
# Name: Consumer ID, dtype: int64

# %%
data.groupby(['Delivery Region','Is New'])['Consumer ID'].size().unstack().plot(kind='bar',stacked=True)
plt.title('Total Customers vs New Customers')
plt.show()

# %%
data.head(3)
# Out:
#   Customer placed order datetime Placed order with restaurant datetime  \
# 0                    14 20:27:45                           14 20:29:41
# 1                    07 20:16:28                           07 20:17:32
# 2                    13 19:35:09                           13 19:39:26
#
#   Driver at restaurant datetime Delivered to consumer datetime  Driver ID  \
# 0                   14 20:39:32                    14 20:52:03         86
# 1                   07 20:36:00                    07 20:49:02        325
# 2                   13 20:28:16                    13 20:52:44        200
#
#    Restaurant ID  Consumer ID  Is New Delivery Region  Is ASAP  Order total  \
# 0             12            5   False       Palo Alto     True        20.45
# 1             66            5   False       Palo Alto     True        40.62
# 2            124            5   False       Palo Alto     True        37.78
#
#    Amount of discount  Amount of tip  Refunded amount  \
# 0               20.45           3.07              0.0
# 1               40.62           3.73              0.0
# 2               37.78           1.89              0.0
#
#    Total_Delivery_Time(mins)  Total_after_disc  is_new_counts
# 0                  24.300000               0.0            1.0
# 1                  32.566667               0.0            1.0
# 2                  77.583333               0.0            1.0

# %%
#Create column to count the number of times a Customer's "Is New" value = True
df = data[data['Is New']==True].groupby('Delivery Region')['Consumer ID'].value_counts().loc[lambda x : x>1].reset_index(name='count')[['Consumer ID', 'count']]
dic_vals= pd.Series(df['count'].values, index=df['Consumer ID']).to_dict()
data['is_new_counts'] = data["Consumer ID"].map(dic_vals, na_action= 1).fillna(1)

# %%
# First time customer orders DISCREPANCIES - BIGGEST OFFENDERS
data[data['Is New']==True].groupby('Delivery Region')['Consumer ID'].value_counts().loc[lambda x : x>1].reset_index(name='count').sort_values(by=['count'], \
ascending=False).head(30)
# Out:
#     Delivery Region  Consumer ID  count
# 136       Palo Alto          514     12
# 0     Mountain View         2469      9
# 137       Palo Alto         9798      9
# 139       Palo Alto        78977      7
# 138       Palo Alto          459      7
# 536        San Jose        79259      6
# 535        San Jose        56015      6
restaurant ID  Consumer ID  Is New Delivery Region  Is ASAP  \
# 15                68           15    True       Palo Alto     True
# 16                86           15    True       Palo Alto     True
# 18               232           15    True       Palo Alto     True
# 33                 9           32    True       Palo Alto     True
# 34                 9           32    True       Palo Alto     True
# 218               63          358    True       Palo Alto     True
# 219              205          358    True       Palo Alto     True
# 249               27          430    True       Palo Alto     True
# 252               28          430    True       Palo Alto     True
# 253               62          430    True       Palo Alto     True
# 283              107          459    True       Palo Alto    False
# 282              107          459    True       Palo Alto    False
# 281              106          459    True       Palo Alto    False
# 277               79          459    True       Palo Alto    False
# 274               58          459    True       Palo Alto    False
# 271               15          459    True       Palo Alto     True
# 269               12          459    True       Palo Alto    False
# 305                9          497    True       Palo Alto    False
# 307               18          497    True       Palo Alto     True
# 309               47          497    True       Palo Alto    False
# 310               97          497    True       Palo Alto     True
# 367              232          514    True       Palo Alto     True
# 362              124          514    True       Palo Alto     True
# 361              123          514    True       Palo Alto     True
# 354               72          514    True       Palo Alto     True
# 352               68          514    True       Palo Alto     True
# 351               66          514    True       Palo Alto     True
# 349               62          514    True       Palo Alto     True
# 346               48          514    True       Palo Alto     True
# 344               26          514    True       Palo Alto     True
# ...              ...          ...     ...             ...      ...
# 16083             45       105800    True   Mountain View     True
# 16118            187       106539    True        San Jose    False
# 16119            194       106539    True        San Jose     True
# 16164            181       107146    True        San Jose     True
# 16166            190       107146    True        San Jose     True
# 16197            219       107475    True       Palo Alto     True
# 16199            353       107475    True       Palo Alto     True
# 16357             43       110118    True   Mountain View    False
# 16358            241       110118    True   Mountain View     True
# 16359            264       110118    True   Mountain View     True
# 16364            201       110246    True        San Jose     True
# 16365            322       110246    True        San Jose     True
# 16451            190       111891    True        San Jose     True
# 16450            170       111891    True        San Jose     True
# 16489            270       112981    True        San Jose     True
# 16490            297       112981    True        San Jose     True
# 16499             30       113125    True   Mountain View     True
# 16500             41       113125    True   Mountain View     True
# 16538            347       113486    True   Mountain View     True
# 16539            347       113486    True   Mountain View     True
# 16567             72       156373    True       Palo Alto     True
# 16568             81       156373    True       Palo Alto     True
# 16595            300       156769    True        San Jose     True
# 16596            331       156769    True        San Jose     True
# 16683             90       158583    True   Mountain View     True
# 16684             90       158583    True   Mountain View     True
# 16736            220       190880    True       Palo Alto     True
# 16737            220       190880    True       Palo Alto     True
# 16944            239       195843    True   Mountain View    False
# 16945            264       195843    True   Mountain View    False
#
#        Order total  Amount of discount  Amount of tip  Refunded amount  \
# 15           49.88                0.00           2.01             0.00
# 16           25.68                0.00           0.90             0.00
# 18           64.18                0.00           2.67             0.00
# 33           35.91                0.00           5.39             0.00
# 34           43.52                0.00           7.00             0.00
# 218          31.39                0.00           2.33             0.00
# 219          23.29                0.00           1.59             0.00
# 249          47.33                0.00           1.90             0.00
# 252          44.99                0.00           1.79             0.00
# 253          46.78                0.00           1.87             0.00
# 349                    43.700000              0.00           12.0
# 346                    24.100000              0.00           12.0
# 344                    51.416667              9.74           12.0
# ...                          ...               ...            ...
# 16083                  52.166667             43.99            3.0
# 16118                 125.800000             42.80            2.0
# 16119                        NaN             46.76            2.0
# 16164                  42.966667             39.04            2.0
# 16166                  53.433333             22.20            2.0
# 16197                  52.583333             23.82            2.0
# 16199                  33.550000             20.08            2.0
# 16357                  42.750000              5.24            3.0
# 16358                  68.383333             37.49            3.0
# 16359                  37.450000             21.21            3.0
# 16364                  55.400000             49.33            2.0
# 16365                  42.416667            114.40            2.0
# 16451                  42.883333              8.16            2.0
# 16450                  38.050000             28.84            2.0
# 16489                  65.916667             50.04            2.0
# 16490                  35.333333             65.67            2.0
# 16499                  52.733333             86.48            2.0
# 16500                  24.700000             78.68            2.0
# 16538                  31.550000             13.59            2.0
# 16539                  30.483333             24.43            2.0
# 16567                  40.866667             39.14            2.0
# 16568                  33.916667             53.80            2.0
# 16595                  47.533333             42.35            2.0
# 16596                  72.100000             50.47            2.0
# 16683                  25.433333             18.98            2.0
# 16684                  30.083333             29.82            2.0
# 16736                  41.933333             18.43            2.0
# 16737                  46.900000             24.43            2.0
# 16944                 247.900000             27.68            2.0
# 16945                 843.516667             26.01            2.0
#
#        Possible_Fraud
# 15                  0
# 16                  0
# 18                  0
# 33                  0
# 34                  0
# 218                 0
# 219                 0
# 249                 0
# 252                 0
# 253                 0
# 283                 0
# 282                 0
# 281                 0
# 277                 0
# 274                 0
# 271                 0
# 269                 0
# 305                 0
# 307                 0
# 309                 0
# 310                 1
# 367                 1
# 362                 1
# 361                 1
# 354                 1
# 352                 1
# 351                 1
# 349                 1
# 346                 1
# 344                 1
# ...               ...
# 16083               1
# 16118               0
# 16119               1
# 16164               1
# 16166               0
# 16197               1
# 16199               0
# 16357               1
# 16358               0
# 16359               1
# 16364               1
# 16365               0
# 16451               1
# 16450               0
# 16489               0
# 16490               1
# 16499               0
# 16500               1
# 16538               1
# 16539               0
# 16567               0
# 16568               0
# 16595               1
# 16596               0
# 16683               1
# 16684               0
# 16736               1
# 16737               0
# 16944               1
# 16945               0
#
# [1738 rows x 18 columns]

# %%
first_time_order_fraud.groupby(['Delivery Region']).agg({'Consumer ID':'count','Amount of discount':['sum', 'mean']})#.sort_values(by='Consumer ID', ascending=False)
# Out:
#                 Consumer ID Amount of discount
#                       count                sum      mean
# Delivery Region
# Mountain View           398             223.18  0.560754
# Palo Alto              1040            1053.70  1.013173
# San Jose                300             271.00  0.903333

# %%
first_time_order_fraud[first_time_order_fraud['Amount of discount']>0].sort_values(by=['Consumer ID'])
# Out:
#       Customer placed order datetime Placed order with restaurant datetime  \
# 310                      21 02:46:02                           21 02:55:53
# 362                      06 19:20:32                           06 19:23:52
# 361                      02 20:11:09                           02 20:15:32
# 354                      13 03:47:04                           13 03:51:15
# 352                      14 20:47:37                           14 20:47:55
# 351                      16 20:11:12                           16 20:12:09
# 367                      15 03:40:04                           15 03:42:22
# 346                      29 03:20:13                           29 03:20:30
# 344                      10 20:26:56                           10 20:27:37
# 339                      17 03:39:24                           17 03:41:02
# 11674             96        35194    True       Palo Alto     True
# 11922             19        39968    True       Palo Alto     True
# 12138             79        44711    True       Palo Alto     True
# 12580            159        56015    True        San Jose    False
# 12661            127        57105    True        San Jose     True
# ...              ...          ...     ...             ...      ...
# 15363            227        94477    True   Mountain View     True
# 15371            187        94583    True        San Jose     True
# 15385             28        94768    True       Palo Alto     True
# 15458            222        96423    True        San Jose     True
# 15514            107        96913    True       Palo Alto     True
# 15624             43        98316    True   Mountain View     True
# 15658              5        98669    True       Palo Alto     True
# 15731             53        99296    True   Mountain View     True
# 15774            289       100604    True        San Jose     True
# 15785             41       100694    True   Mountain View     True
# 15901            160       102485    True        San Jose     True
# 15979            297       103874    True        San Jose     True
# 16004             46       104229    True   Mountain View     True
# 16018            222       104395    True        San Jose     True
# 16066            194       105633    True        San Jose     True
# 16083             45       105800    True   Mountain View     True
# 16119            194       106539    True        San Jose     True
# 16164            181       107146    True        San Jose     True
# 16197            219       107475    True       Palo Alto     True
# 16357             43       110118    True   Mountain View    False
# 16359            264       110118    True   Mountain View     True
# 16364            201       110246    True        San Jose     True
# 16451            190       111891    True        San Jose     True
# 16490            297       112981    True        San Jose     True
# 16500             41       113125    True   Mountain View     True
# 16538            347       113486    True   Mountain View     True
# 16595            300       156769    True        San Jose     True
# 16683             90       158583    True   Mountain View     True
# 16736            220       190880    True       Palo Alto     True
# 16944            239       195843    True   Mountain View    False
#
#        Order total  Amount of discount  Amount of tip  Refunded amount  \
# 310          36.34               10.00           1.82             0.00
# 362          31.27               31.27           3.48             0.00
# 361          19.57               19.57           1.24             0.00
# 354          70.55               70.55           5.92             0.00
# 352          46.78               46.78           7.02             0.00
# 351          53.64               53.64           2.19             2.19
# 367         109.79              109.79           4.77             0.00
# 346          72.67               72.67           6.13             0.00
# 344          97.03               87.29           5.00             0.00
# 339          98.77               98.77           8.53             0.00
# 336          25.03               25.03           4.00             0.00
# 331          61.79               61.79           5.13             0.00
# 349         150.00              150.00          12.69             0.00
# 960          30.96                5.00           1.14             0.00
# 3096         25.74               21.55           2.57             0.00
# 3154         50.04                5.00           2.50             0.00
# 3477        114.49                6.00           4.98             0.00
# 4164         39.01               10.00           1.95             0.00
# 4204         36.34                6.00           1.82             0.00
# 9222         45.53               15.00           3.63             0.00
# 9489         24.53                6.00           1.23             0.00
# 10007        17.19                6.00           2.58             0.00
# 10272        53.69               45.18           2.19             0.00
# 10636        27.70                6.00           1.39             0.00
# 11165        43.44                6.00           5.15             0.00
# 11674        46.24                6.00           5.55             0.00
# 11922        21.22                5.00           0.70             0.00
# 12138        59.41                6.00           2.97             0.00
# 12580        51.13               12.00           6.22             0.00
# 12661       113.66                6.00          17.05             0.00
# ...            ...                 ...            ...              ...
# 15363        32.05                6.00           5.00             0.00
# 15371        32.54                6.00           3.66             0.00
# 15385        57.49                6.00           2.87             0.00
# 15458        19.56                6.00           2.93             0.00
# 15514        65.76                6.00           2.74             0.00
# 15624        70.11               38.00           3.51             0.00
# 15658        91.70                6.00           3.94             0.00
# 15731        28.78                6.00           2.09             0.00
# 15774        44.28                6.00           3.00             0.00
# 15785        34.22                6.00           0.00             0.00
# 15901        23.89                6.00           5.00             0.00
# 15979        51.67                6.00           2.09             0.00
# 16004        44.01                6.00           3.49             0.00
# 16018        47.13                6.00           1.89             0.00
# 16066        39.17                6.00           4.00             0.00
# 16083        49.99                6.00           2.02             0.00
# 16119        52.76                6.00           4.30             0.00
# 16164        45.04                6.00           5.38             0.00
# 16197        29.82                6.00           3.28             0.00
# 16357        15.24               10.00           0.00             0.00
# 16359        27.21                6.00           0.97             0.00
# 16364        55.33                6.00           6.80             0.00
# 16451        14.16                6.00           2.12             0.00
# 16490        71.67                6.00          13.00             0.00
# 16500        84.68                6.00           5.00             0.00
# 16538        19.59                6.00           0.98             0.00
# 16595        48.35                6.00           1.94             0.00
# 16683        24.98                6.00           0.87             0.00
# 16736        24.43                6.00           1.69             0.00
# 16944        33.68                6.00           1.27             0.00
#
#        Total_Delivery_Time(mins)  Total_after_disc
# 310                    36.333333             26.34
# 362                    31.616667              0.00
# 361                    31.116667              0.00
# 354                    23.750000              0.00
# 352                    42.000000              0.00
# 351                    29.533333              0.00
# 367                    47.933333              0.00
# 346                    24.100000              0.00
# 344                    51.416667              9.74
# 339                    25.950000              0.00
# 336                    25.500000              0.00
# 331                    26.916667              0.00
# 349                    43.700000              0.00
# 960                    26.200000             25.96
# 3096                   60.500000              4.19
# 3154                         NaN             45.04
# 3477                   30.716667            108.49
# 4164                  190.900000             29.01
# 4204                   38.033333             30.34
# 9222                   72.900000             30.53
# 9489                         NaN             18.53
# 10007                  55.566667             11.19
# 10272                  36.466667              8.51
# 10636                  62.500000             21.70
# 11165                  68.533333             37.44
# 11674                  42.783333             40.24
# 11922                  32.566667             16.22
# 12138                  26.616667             53.41
# 12580                        NaN             39.13
# 12661                  47.683333            107.66
# ...                          ...               ...
# 15363                  51.850000             26.05
# 15371                  50.566667             26.54
# 15385                  36.183333             51.49
# 15458                  47.783333             13.56
# 15514                  53.700000             59.76
# 15624                  51.916667             32.11
# 15658                  55.350000             85.70
# 15731                  35.416667             22.78
# 15774                  50.550000             38.28
# 15785                  58.583333             28.22
# 15901                  55.933333             17.89
# 15979                  45.066667             45.67
# 16004                  35.033333             38.01
# 16018                  49.333333             41.13
# 16066                  29.300000             33.17
# 16083                  52.166667             43.99
# 16119                        NaN             46.76
# 16164                  42.966667             39.04
# 16197                  52.583333             23.82
# 16357                  42.750000              5.24
# 16359                  37.450000             21.21
# 16364                  55.400000             49.33
# 16451                  42.883333              8.16
# 16490                  35.333333             65.67
# 16500                  24.700000             78.68
# 16538                  31.550000             13.59
# 16595                  47.533333             42.35
# 16683                  25.433333             18.98
# 16736                  41.933333             18.43
# 16944                 247.900000             27.68
#
# [109 rows x 16 columns]

# %%
# Customers with multiple "is_new"= True instances and who have received a discount
df_agg= first_time_order_fraud[first_time_order_fraud['Amount of discount']>0].groupby('Consumer ID').agg({'Consumer ID':'count', 'Amount of discount':['sum', 'mean'], \
'Order total':['sum', 'mean'],'Total_after_disc':['sum', 'mean']})

df_agg.columns = [' '.join(col) for col in df_agg.columns]
df_agg.sort_values(by='Consumer ID count', ascending=False).loc[df_agg['Consumer ID count'] > 1]
# Out:
#              Consumer ID count  Amount of discount sum  \
# Consumer ID
# 514                         12                  827.15
# 81147                        2                   16.00
# 110118                       2                   16.00
#
#              Amount of discount mean  Order total sum  Order total mean  \
# Consumer ID
# 514                        68.929167           836.89         69.740833
# 81147                       8.000000            66.28         33.140000
# 110118                      8.000000            42.45         21.225000
#
#              Total_after_disc sum  Total_after_disc mean
# Consumer ID
# 514                          9.74               0.811667
# 81147                       50.28              25.140000
# 110118                      26.45              13.225000

# %%
#Add Possible Fraud Column
data['Possible_Fraud']= np.where( (data['is_new_counts'].astype(int) >1) & (data['Amount of discount'].astype(int) >0), 1, 0)

# %%
data.groupby(['Delivery Region'])['Possible_Fraud'].sum().plot(kind='bar',stacked=True)
plt.title('Number of Fraud Instances per City')
plt.show()

# %%
#NEW customer analysis, first time customer orders
round(data[data['Is New']==True].groupby(['Delivery Region']).agg({'Consumer ID': 'count','Total_Delivery_Time(mins)':'mean','Total_after_disc':'mean'
                                            ,'Amount of discount':'mean'}).sort_values(by='Consumer ID', ascending=False),2)
# Out:
#                  Consumer ID  Total_Delivery_Time(mins)  Total_after_disc  \
# Delivery Region
# Palo Alto               2123                      59.67             51.01
# Mountain View            720                      59.81             56.18
# San Jose                 666                      56.18             41.74
# None                       3                     787.20            593.98
#
#                  Amount of discount
# Delivery Region
# Palo Alto                      1.40
# Mountain View                  1.22
# San Jose                       2.22
# None                           0.00

# %%
city_grouped = data.groupby(['Delivery Region'])
city_grouped['Is New'].value_counts().unstack()
# Out:
# Is New           False  True
# Delivery Region
# Mountain View     3040    720
# None                23      3
# Palo Alto         9310   2123
# San Jose          2193    666

# %%
round(100*city_grouped['Is New'].value_counts(normalize=True).unstack(),2)
# Out:
# Is New           False  True
# Delivery Region
# Mountain View    80.85  19.15
# None             88.46  11.54
# Palo Alto        81.43  18.57
# San Jose         76.71  23.29

# %%
#City with the most repeat customers
'''Filter Dataframe for ONLY customers that have more than one order'''
only_cus_repeats= data[data['Consumer ID'].isin(data['Consumer ID'].value_counts()[data['Consumer ID'].value_counts()>1].index)]

only_cus_repeats.groupby(['Delivery Region']).agg({'Consumer ID': 'nunique'}).sort_values(by='Consumer ID', ascending=False)
# Out:
#                  Consumer ID
# Delivery Region
# Palo Alto               2069
# Mountain View            705
# San Jose                 579
# None                       1

# %%
#Unique customers for Restaurants in each city
data.groupby(['Restaurant ID','Delivery Region']).agg({'Consumer ID': 'nunique'}).sort_values(by='Consumer ID', ascending=False).head(25)
# Out:
#                                Consumer ID
# Restaurant ID Delivery Region
# 20            Palo Alto                515
# 9             Palo Alto                431
# 8             Palo Alto                401
# 107           Palo Alto                340
# 68            Palo Alto                310
# 12            Palo Alto                308
# 10            Palo Alto                276
# 63            Palo Alto                250
# 3             Palo Alto                199
# 28            Palo Alto                193
# 27            Palo Alto                192
# 205           Palo Alto                173
# 5             Palo Alto                158
# 83            Palo Alto                158
# 194           San Jose                 155
# 6             Palo Alto                150
# 98            Mountain View            148
# 62            Palo Alto                143
# 48            Palo Alto                142
# 100           Palo Alto                142
# 233           Palo Alto                128
# 72            Palo Alto                126
# 76            Mountain View            125
# 44            Mountain View            125
# 30            Mountain View            122

# %%
#Total number of orders for Restaurants in each city
data.groupby(['Restaurant ID','Delivery Region']).agg({'Consumer ID': 'count'}).sort_values(by='Consumer ID', ascending=False).head(25)
# Out:
#                                Consumer ID
# Restaurant ID Delivery Region
# 8             Palo Alto                744
# 20            Palo Alto                716
# 9             Palo Alto                713
# 107           Palo Alto                491
# 12            Palo Alto                472
# 68            Palo Alto                415
# 10            Palo Alto                381
# 63            Palo Alto                375
# 3             Palo Alto                266
# 28            Palo Alto                245
# 27            Palo Alto                239
# 83            Palo Alto                217
# 43            Mountain View            212
# 205           Palo Alto                205
# 98            Mountain View            201
# 6             Palo Alto                199
# 62            Palo Alto                196
# 5             Palo Alto                193
# 48            Palo Alto                191
# 44            Mountain View            189
# 194           San Jose                 186
# 233           Palo Alto                175
# 170           San Jose                 174
# 100           Palo Alto                169
# 211           Palo Alto                155

# %%
data.groupby('Restaurant ID').agg({'Consumer ID': 'count'}).sort_values(by='Consumer ID', ascending=False).head(25)
# Out:
#                Consumer ID
# Restaurant ID
# 8                      747
# 20                     723
# 9                      717
# 107                    494
# 12                     472
# 63                     438
# 68                     417
# 10                     381
# 3                      267
# 76                     263
# 28                     245
# 27                     239
# 62                     223
# 43                     220
# 83                     219
# 98                     218
# 205                    208
# 48                     206
# 44                     200
# 6                      199
# 5                      193
# 194                    186
# 233                    175
# 170                    174
# 100                    171

# %% [markdown]
# # Discounts Analysis

# %%
round(100*data[data['Amount of discount']>0]['Delivery Region'].value_counts(normalize=True),2)
# Out:
# Palo Alto        51.76
# San Jose         30.16
# Mountain View    18.08
# Name: Delivery Region, dtype: float64

# %%
data.loc[data['Total_Delivery_Time(mins)'].idxmax()]
# Out:
# Customer placed order datetime           23 03:22:30
# Placed order with restaurant datetime            NaN
# Driver at restaurant datetime                    NaN
# Delivered to consumer datetime           23 23:32:28
# Driver ID                                         34
# Restaurant ID                                     11
# Consumer ID                                   113389
# Is New                                         False
# Delivery Region                            Palo Alto
# Is ASAP                                        False
# Order total                                   343.32
# Amount of discount                                 0
# Amount of tip                                     50
# Refunded amount                                    0
# Total_Delivery_Time(mins)                    1209.97
# Total_after_disc                              343.32
# is_new_counts                                      1
# Possible_Fraud                                     0
# Name: 16531, dtype: object

# %%
data.sort_values(by='Total_Delivery_Time(mins)', ascending=False).head(25)
# Out:
#       Customer placed order datetime Placed order with restaurant datetime  \
# 16531                    23 03:22:30                                   NaN
# 14965                    09 01:16:00                           09 17:24:22
# 12019                    18 00:33:51                           18 18:49:53
# 6100                     29 00:23:25                           29 18:41:53
# 5536                     04 00:00:18                           04 18:04:33
# 13087                    18 00:04:26                           18 17:09:59
# 10235                    05 00:53:54                           05 18:10:07
# 12021                    25 00:18:47                           25 17:46:00
# 2993                     03 00:36:44                           03 17:29:06
# 896                      03 00:26:40                           03 17:49:33
# 1393                     24 00:02:41                           24 17:12:25
# 10207                    04 01:01:54                           04 17:56:16
# 16061                    18 01:09:32                           18 04:11:25
# 12575                    10 01:22:03                           10 17:44:32
# 2993        126.18                 0.0          10.50             0.00
# 896         136.40                 0.0          17.16             0.00
# 1393         59.61                 0.0           2.46             0.00
# 10207       126.62                 0.0           5.27            32.44
# 16061       585.98                 6.0          79.17             0.00
# 12575       222.92                 0.0          29.09             0.00
# 15878        83.70                 6.0           7.14             0.00
# 7440         36.52                 0.0           2.80             0.00
# 7502        141.68                 0.0           5.96             0.00
# 5315         33.68                 0.0           1.27             0.00
# 472          44.01                 6.0           1.74             0.00
# 17979       129.83                 0.0          16.25             0.00
# 4494        156.87                 0.0          19.65             0.00
# 17535        42.92                 0.0           1.69             0.00
# 17020        91.21                 6.0           5.00             0.00
# 12356        28.78                 0.0           0.00             0.00
# 3382         50.37                 0.0           2.04             0.00
#
#        Total_Delivery_Time(mins)  Total_after_disc  is_new_counts  \
# 16531                1209.966667            343.32            1.0
# 14965                1147.733333            184.35            2.0
# 12019                1144.850000             60.79            1.0
# 6100                 1144.283333             15.24            1.0
# 5536                 1139.383333            102.24            1.0
# 13087                1138.700000            203.18            1.0
# 10235                1103.900000            160.12            3.0
# 12021                1095.366667             82.13            1.0
# 2993                 1092.016667            126.18            1.0
# 896                  1091.516667            136.40            3.0
# 1393                 1089.166667             59.61            1.0
# 10207                1076.133333            126.62            1.0
# 16061                1056.183333            579.98            1.0
# 12575                1050.100000            222.92            6.0
# 15878                1047.883333             77.70            1.0
# 7440                 1043.816667             36.52            1.0
# 7502                 1028.100000            141.68            1.0
# 5315                 1025.633333             33.68            1.0
# 472                  1025.566667             38.01            1.0
# 17979                1024.266667            129.83            6.0
# 4494                 1023.566667            156.87            1.0
# 17535                1018.616667             42.92            1.0
# 17020                1011.400000             85.21            1.0
# 12356                1007.816667             28.78            1.0
# 3382                  996.600000             50.37            1.0
#
#        Possible_Fraud
# 16531               0
# 14965               1
# 12019               0
# 6100                0
# 5536                0
# 13087               0
# 10235               0
# 12021               0
# 2993                0
# 896                 0
# 1393                0
# 10207               0
# 16061               0
# 12575               0
# 15878               0
# 7440                0
# 7502                0
# 5315                0
# 472                 0
# 17979               0
# 4494                0
# 17535               0
# 17020               0
# 12356               0
# 3382                0

# %%
data[data['Amount of discount']>0].groupby('Delivery Region')['Amount of discount'].describe()
# Out:
#                   count       mean        std   min  25%  50%  75%     max
# Delivery Region
# Mountain View     504.0   7.841865   8.871630  0.19  6.0  6.0  6.0  121.36
# Palo Alto        1443.0  10.482675  19.052321  1.00  6.0  6.0  6.0  187.88
# San Jose          841.0   6.477693   3.946079  5.00  6.0  6.0  6.0   72.98

# %%
round(data[data['Amount of discount']>0].groupby(['Delivery Region']).agg({'Consumer ID': 'count','Total_after_disc':'mean'
                                            ,'Amount of discount':'mean'}).sort_values(by='Consumer ID', ascending=False),2)
# Out:
#                  Consumer ID  Total_after_disc  Amount of discount
# Delivery Region
# Palo Alto               1443             39.80               10.48
# San Jose                 841             37.45                6.48
# Mountain View            504             39.98                7.84

# %%
# Avg Delivery time for orders WITH discounts vs WITHOUT
(round(data[data['Amount of discount'] >0]['Total_Delivery_Time(mins)'].mean(), 2), round(data[data['Amount of discount'] ==0]['Total_Delivery_Time(mins)'].mean(),2))
# Out:
# (57.18, 57.0)

# %%
cor_rel.loc[cor_rel['Total_Delivery_Time(mins)'].idxmin()]
# Out:
# Customer placed order datetime           21 06:13:32
# Placed order with restaurant datetime    21 06:14:13
# Driver at restaurant datetime                    NaN
# Delivered to consumer datetime           21 06:14:00
# Driver ID                                         25
# Restaurant ID                                     20
# Consumer ID                                     2032
# Is New                                         False
# Delivery Region                            Palo Alto
# Is ASAP                                        False
# Order total                                    14.08
# Amount of discount                             14.08
# Amount of tip                                      0
# Refunded amount                                    0
# Total_Delivery_Time(mins)                   0.466667
# Total_after_disc                                   0
# is_new_counts                                      1
# Possible_Fraud                                     0
# Name: 2028, dtype: object

# %%
# There is a very weak negative correlation between Total Delivery Time and the Amount of Discount Applied to Orders
data[data['Amount of discount'] >0][['Amount of discount','Total_Delivery_Time(mins)']].corr()
# Out:
#                            Amount of discount  Total_Delivery_Time(mins)
# Amount of discount                   1.000000                  -0.021475
# Total_Delivery_Time(mins)           -0.021475                   1.000000

# %%
cor_rel = data[data['Amount of discount'] >0].copy()
cor_rel['Amount of discount']
cor_rel['Total_Delivery_Time(mins)']

# %%
cor_rel['Amount of discount'].corr(cor_rel['Total_Delivery_Time(mins)'])
# Out:
# -0.021475389785261815

# %%
sns.lmplot(x='Amount of discount', y='Total_Delivery_Time(mins)', data=data)
# Out:
# /anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
import seaborn as sns

sns.lmplot(x='Amount of discount', y='Total_Delivery_Time(mins)', data=cor_rel)
# Out:
# /anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.lmplot(x='Amount of discount', y='Total_Delivery_Time(mins)', data=cor_rel[cor_rel['Delivery Region']=='Palo Alto'])
# Out:
# /anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
data[data['Amount of discount'] >0].groupby('Delivery Region').agg({'Amount of discount': ['count', 'mean', 'sum'], 'Total_Delivery_Time(mins)':'mean'}).reset_index()
# Out:
#   Delivery Region Amount of discount                       \
#                                count       mean       sum
# 0   Mountain View                504   7.841865   3952.30
# 1       Palo Alto               1443  10.482675  15126.50
# 2        San Jose                841   6.477693   5447.74
#
#   Total_Delivery_Time(mins)
#                        mean
# 0                 56.412256
# 1                 59.562154
# 2                 53.591547

# %% [markdown]
# # Conclusions/ Experimental Setup

# %% [markdown]
# From what I can glean, it's clear to see that Palo Alto is by far the most profitable market for DoorDash, it has the most customers (overall), the most repeat customers, the highest avg total order amount, the most popular restaurants (most # of orders & customers/top 12 are all from PA).
#
# However, it does also have the longest average delivery team and the second lowest average discount amount for first time customer orders($1.40) after Mountain View($1.22).
# A deep dive into customer orders with discounts reveals that Palo Alto does have the highest average discount per order and the highest count of orders with discounts,
# with more than 50% of all orders with discounts across all cities.
#
# The main focus for promos such as free delivery and promo credits should be on Palo Alto, to take advantage of the strong/large customer base, and more importantly
# for new customers making their first orders.
#
# I would like to setup an experiment to track Customers who are abusing first-time order promo credits on a repeated basis. A simple Logistic Regression model can be implemented
# to predict potential fradulent behavior from customers. I'm sure by now DoorDash has many safeguards and sophisticated models in place to mitigate against fradulent behavior,
# I would genuinely love to be a part of that effort.
#
# I am making the following assumptions for fradulent customer behavior:
# - If a customer is categorized as a first time customer more than once then the customer has figured out a loophole for promo credits and is taking advantage of it.
# - It is impossible to determine the the reason for the discounts being applied to orders with this data
# - I am assuming they're first time promo-credits considering that the avg delivery time for orders with & w/o discounts are the same (57 mins) and a very weak correlation between Delivery time and the amount of discount applied
#
# For instance, consumer ID 514 has placed the most orders and has received $827.15 worth of discounts and has also been categorized as a new customer 12 times.
# Customers such as these have to be identified early to prevent them from racking up unearned free credits. The first step would be to create a watchlist for customers that
# have been categorized as first-time customers more than once.
#
# Drawbacks:
# The operational hazards that could occur from implementing such a solution are:
# 1.) Overhead- additional time spent by employees looking into specific customers and their fradulent activity.
# 2.) Inaccurate predictions
# 3.) Predictive Modeling Discrimination/Calibration
#
# Success Metrics:
# 1.) Accuracy of the model's predictions
# 2.) Cost savings from preventing fraud (free credit)
# 3.) Model could help reveal loopholes in product offering/service

# %% [markdown]
# # Logistic Regression Model for Predicting Fradulent Customers

# %%
from sklearn import preprocessing
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

# %%
experiment = data.copy()
experiment.head(3)
# Out:
#   Customer placed order datetime Placed order with restaurant datetime  \
# 0                    14 20:27:45                           14 20:29:41
# 1                    07 20:16:28                           07 20:17:32
# 2                    13 19:35:09                           13 19:39:26
#
#   Driver at restaurant datetime Delivered to consumer datetime  Driver ID  \
# 0                   14 20:39:32                    14 20:52:03         86
# 1                   07 20:36:00                    07 20:49:02        325
# 2                   13 20:28:16                    13 20:52:44        200
#
#    Restaurant ID  Consumer ID  Is New Delivery Region  Is ASAP  Order total  \
# 0             12            5   False       Palo Alto     True        20.45
# 1             66            5   False       Palo Alto     True        40.62
# 2            124            5   False       Palo Alto     True        37.78
#
#    Amount of discount  Amount of tip  Refunded amount  \
# 0               20.45           3.07              0.0
# 1               40.62           3.73              0.0
# 2               37.78           1.89              0.0
#
#    Total_Delivery_Time(mins)  Total_after_disc  is_new_counts  Possible_Fraud
# 0                  24.300000               0.0            1.0               0
# 1                  32.566667               0.0            1.0               0
# 2                  77.583333               0.0            1.0               0

# %%
data['Delivery Region'].value_counts()
# Out:
# Palo Alto        11433
# Mountain View     3760
# San Jose          2859
# None                26
# Name: Delivery Region, dtype: int64

# %%
experiment['Delivery Region'].value_counts()
# Out:
# 2    11433
# 0     3760
# 3     2859
# 1       26
# Name: Delivery Region, dtype: int64

# %%
X = experiment.select_dtypes(include=[object])
X= X[['Delivery Region']]

# %%
# 1. INSTANTIATE
# encode labels with value between 0 and n_classes-1.
le = preprocessing.LabelEncoder()

# 2/3. FIT AND TRANSFORM
# use df.apply() to apply le.fit_transform to all columns
X_2 = X.apply(le.fit_transform)
experiment.loc[:, 'Delivery Region'] = X_2.values

# %%
features = ['Is New','Delivery Region','Amount of discount','Refunded amount','Total_after_disc','is_new_counts']
target = 'Possible_Fraud'

# %%
# For Is New: False will be 0, True will be 1
experiment['Is New'] = experiment['Is New'].map({'False':0, 'True':1}).astype(int)

experiment['Possible_Fraud'] = experiment['Possible_Fraud'].astype(int)

# %%
experiment['Possible_Fraud'].value_counts(normalize=True)
# Out:
# 0    0.987388
# 1    0.012612
# Name: Possible_Fraud, dtype: float64

# %%
X = experiment[features].values
y = experiment[target].values

# %%
exp_classifier_logreg = LogisticRegression(C=2)
exp_classifier_logreg.fit(X, y)
# Out:
# LogisticRegression(C=2, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
experiment['predictions_logreg'] = exp_classifier_logreg.predict(X)
confusion_matrix = pd.crosstab(experiment['predictions_logreg'], experiment['Possible_Fraud'])
confusion_matrix
# Out:
# Possible_Fraud          0    1
# predictions_logreg
# 0                   17842  161
# 1                       8   67

# %%
ac = (confusion_matrix.loc[0,0] + confusion_matrix.loc[1,1])/experiment.shape[0]
print("Accuracy: {}".format(ac))
# Out:
# Accuracy: 0.9906516207545082

# %%
fraud_classifier_rf = RandomForestClassifier()
fraud_classifier_rf.fit(X,y)
experiment['predictions_rf'] = fraud_classifier_rf.predict(X)

# %%
confusion_matrix = pd.crosstab(experiment['predictions_rf'], experiment['Possible_Fraud'])
confusion_matrix
# Out:
# Possible_Fraud      0    1
# predictions_rf
# 0               17850    0
# 1                   0  228

# %%
ac = (confusion_matrix.loc[0,0] + confusion_matrix.loc[1,1])/experiment.shape[0]
print("Accuracy: {}".format(ac))
# Out:
# Accuracy: 1.0

# %%
features
# Out:
# ['Is New',
#  'Delivery Region',
#  'Amount of discount',
#  'Refunded amount',
#  'Total_after_disc',
#  'is_new_counts']

# %%
#Lets Introduce a New Customer Here
'''New Customer has the following entry '''

newcustomer= data[features].iloc[0].copy()
newcustomer['Is New']= True
newcustomer['Amount of discount']= 25
newcustomer['Refunded amount']= 0
newcustomer['Total_after_disc']= 1.50
newcustomer['is_new_counts']=5
newcustomer
# Out:
# Is New                     True
# Delivery Region       Palo Alto
# Amount of discount           25
# Refunded amount               0
# Total_after_disc            1.5
# is_new_counts                 5
# Name: 0, dtype: object

# %%
new_customer = np.array([[1, 2, 25, 0, 1.50, 5 ]])
prediction = fraud_classifier_rf.predict(new_customer)
print("The model predicts that the customer will be:")
if prediction == 1:
    print("Identified as Fraud\n.......Possible Fraud")
else:
    print("A normal Customer")
newcustomer['Possible_Fraud'] = prediction[0]
pd.DataFrame(newcustomer).T
# Out:
# The model predicts that the customer will be:
# Identified as Fraud
# .......Possible Fraud
#   Is New Delivery Region Amount of discount Refunded amount Total_after_disc  \
# 0   True       Palo Alto                 25               0              1.5
#
#   is_new_counts Possible_Fraud
# 0             5              1

# %%
#Lets do it again
'''New Customer has the following entry '''

newcustomer= data[features].iloc[0].copy()
newcustomer['Is New']= True
newcustomer['Amount of discount']= 7
newcustomer['Refunded amount']= 0
newcustomer['Total_after_disc']= 11
newcustomer['is_new_counts']= 1
newcustomer
# Out:
# Is New                     True
# Delivery Region       Palo Alto
# Amount of discount            7
# Refunded amount               0
# Total_after_disc             11
# is_new_counts                 1
# Name: 0, dtype: object

# %%
new_customer = np.array([[1, 2, 7, 0, 11, 1 ]])
prediction = fraud_classifier_rf.predict(new_customer)
print("The model predicts that the customer will be:")
if prediction == 1:
    print("Identified as Fraud\n.......Possible Fraud")
else:
    print("A normal Customer")
newcustomer['Possible_Fraud'] = prediction[0]
pd.DataFrame(newcustomer).T
# Out:
# The model predicts that the customer will be:
# A normal Customer
#   Is New Delivery Region Amount of discount Refunded amount Total_after_disc  \
# 0   True       Palo Alto                  7               0               11
#
#   is_new_counts Possible_Fraud
# 0             1              0
