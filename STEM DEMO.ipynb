# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:109% !important; }</style>"))
# Out:
# <style>.container { width:109% !important; }</style>

# %% [markdown]
# # G SHEET INTEGRATION

# %% [markdown]
# Remember to always share the Google Sheet with mgh-358@massive-current-173408.iam.gserviceaccount.com

# %%
import gspread
import pandas as pd
from oauth2client.service_account import ServiceAccountCredentials

scope = ['https://spreadsheets.google.com/feeds',
         'https://www.googleapis.com/auth/drive']
credentials = ServiceAccountCredentials.from_json_keyfile_name('My Project 1-c799865aecf9.json', scope)
gc = gspread.authorize(credentials)
deals = gc.open("Example")
deals
#wks = gc.open("DealReg").sheet1
#data = pd.DataFrame(wks.get_all_records())
####remember to share google sheet with service_account_ from GCP credentials
# Out:
# <Spreadsheet 'Example' id:16C9Ty6SSMDW0pcBvWYL3mNeWVlpNHQfN28cL2Y2O81s>

# %%
####5 actually means sheet7
dealregg = deals.get_worksheet(5)
bookings = pd.DataFrame(dealregg.get_all_records())
bookings
# Out:
#    Created_date                                               Name  \
# 0    2018-05-29                                 B Bosch - Apps 600
# 1    2018-05-29                                 B Bosch - Apps 600
# 2    2018-05-29                                 B Bosch - Apps 600
# 3    2018-05-29                                 B Bosch - Apps 600
# 4    2018-05-29                                 B Bosch - Apps 600
# 5    2018-07-24  CORPORACIÓN AUTÓNOMA REGIONAL DE BOYACÁ - Apps...
# 6    2018-07-24  CORPORACIÓN AUTÓNOMA REGIONAL DE BOYACÁ - Apps...
# 7    2018-06-25                  Fletes Mexico SA de CV - Apps 223
# 8    2018-06-25                  Fletes Mexico SA de CV - Apps 223
# 9    2018-06-25                  Fletes Mexico SA de CV - Apps 223
# 10   2018-06-25                  Fletes Mexico SA de CV - Apps 223
# 11   2018-06-20                   Grupo ENM, SA. de CV. - Apps 225
# 12   2018-06-20                   Grupo ENM, SA. de CV. - Apps 225
# ...

# %%
####5 actually means sheet7
bookings['enduser_domain']= bookings['enduser_domain'].fillna('N/A')
bookings.drop(columns='V10_oppty', inplace= True)
sku_bookings=bookings.groupby(['Name','partner', 'Partner_Involved_Object__c','customer_accountID','customer','enduser_customer_id','booking_date','Primary_Product_interest__c','Created_date','support_start_date', 'support_end_date','opp_type','enduser_domain','Opportunity_ID_18__c','unify_product_category_2', 'sku_description'], as_index=True).agg({'sku_count':'sum', 'partner_new_amount':'sum'})                        
runningtotal= sku_bookings.groupby(['Name','enduser_customer_id'])['partner_new_amount'].cumsum()
sku_bookings['Running_Total']= runningtotal
sku_bookings['Rebate']= sku_bookings['Running_Total'].apply(lambda x: x*.06 if x>=18000 else 0)

# %%
sku_bookings
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-b5efac4d4264> in <module>()
# ----> 1 sku_bookings
#
# NameError: name 'sku_bookings' is not defined

# %% [markdown]
# # Updating Example with sku_bookings dataframe

# %%
import pygsheets
import pandas as pd
#authorization
gs = pygsheets.authorize(service_account_file='My Project 1-c799865aecf9.json')

# The dataframe to add into the blank sheet
sku_bookings

#open the google spreadsheet (where 'PY to Gsheet Test' is the name of my sheet)
sh = gs.open('Example')

#select the new sheet 
wks = sh[6]

#update the first sheet with sku_bookings, starting at cell B2. 

wks.set_dataframe(sku_bookings.reset_index(), start='A1' ,copy_index=False, copy_head= True, fit=True)


#wks.update_cells(crange='B2',values = bookings)

# %%
wks.get_as_df(has_header=True, index_colum=None, start=None, end=None, numerize=True, empty_value="")
newdata =wks.get_as_df(has_header=True, index_colum=None, start=None, end=None, numerize=True, empty_value="")

# %%
newdata

# %% [markdown]
# # Import Fast Track Data

# %%
fa = gs.open('GCP Fast Track - Tracker') 
ftt2 = fa[3]
ftt2.get_as_df(has_header=True, index_colum=None, start=None, end=None, numerize=True, empty_value="")
fast_track2 =ftt2.get_as_df(has_header=True, index_colum=None, start=None, end=None, numerize=True, empty_value="")

# %%
fast_track2.columns

# %%
col = ['partner_name', 'Fast_Track_Contract', 'booking_month',
       'booking_amount', 'running_certs_total',
       'bookings_over_50k', 'bookings_over50k_running_total',
       'bookings_over_30k', 'bookings_over30k_running_total',
       'eligible_for_rebate', 'requirements_left_for_performancetarget1',
       'requirements_left_for_performancetarget2',
       'requirements_left_for_rebate','contract_effective_date', 'expiration_date', 'date_fasttrack_expires',
       'AUTO_EXT_DATE', 'partner__c','PROGRAMMARKET', 'Region__c', 'months_remaining_incontract',
       'months_remaining_FASTTRACK_eligibility']
fast_track2.loc[:, (col)]

# %%
def p1(fast_track2):
    if fast_track2['Fast_Track_Contract']== 'New Fast Track Contract':
        if fast_track2['running_certs_total'] >= 4 and fast_track2['bookings_over30k_running_total'] <2:
            bkreq = 2 - fast_track2['bookings_over30k_running_total']
            return "{} booking(s) left only.".format(bkreq)
        elif fast_track2['running_certs_total'] < 4 or fast_track2['bookings_over30k_running_total'] <2:
            bkreq = 2 - fast_track2['bookings_over30k_running_total']
            certreq= 4 - fast_track2['running_certs_total']
            return "{} bookings left and {} certs.".format(bkreq, certreq)
        if fast_track2['running_certs_total'] >= 4 and fast_track2['bookings_over30k_running_total'] >=2:
            return "$35,000 Rebate"

# %%
def p2(fast_track2):
    if fast_track2['Fast_Track_Contract']== 'New Fast Track Contract':
        if fast_track2['running_certs_total'] >= 6 and fast_track2['bookings_over50k_running_total'] <2:
            bkreq = 2 - fast_track2['bookings_over50k_running_total']
            return "{} booking(s) left only.".format(bkreq)
        elif fast_track2['running_certs_total'] < 6 or fast_track2['bookings_over50k_running_total'] <2:
            bkreq = 2 - fast_track2['bookings_over50k_running_total']
            certreq= 6 - fast_track2['running_certs_total']
            return "{} bookings left and {} certs.".format(bkreq, certreq)
        if fast_track2['running_certs_total'] >= 6 and fast_track2['bookings_over50k_running_total'] >=2:
            return "$55,000 Rebate"

# %%
fast_track2.loc[:, 'PF1']= fast_track2.apply(p1, axis=1)
fast_track2.loc[:, 'PF2']=fast_track2.apply(p2, axis=1)

# %%
def f(fast_track2):
    if fast_track2['Fast_Track_Contract']== 'Old Fast Track Contract':
        if fast_track2['PROGRAMMARKET']== 'EMERGING MARKET':
            
            if fast_track2['running_certs_total'] >= 6 and fast_track2['bookings_over30k_running_total'] <2:
                bkreq = 2 - fast_track2['bookings_over30k_running_total']
                return "{} booking(s) left only for $30,000 Rebate.".format(bkreq)
            elif fast_track2['running_certs_total'] < 6 or fast_track2['bookings_over30k_running_total'] <2:
                bkreq = 2 - fast_track2['bookings_over30k_running_total']
                certreq= 6 - fast_track2['running_certs_total']
                return "{} bookings and {} certs $30,000 Rebate.".format(bkreq, certreq)
            if fast_track2['running_certs_total'] >= 6 and fast_track2['bookings_over30k_running_total'] >=2:
                return "Eligible for $30,000 Rebate"       
        if fast_track2['PROGRAMMARKET']== 'DEVELOPED MARKET':
            if fast_track2['running_certs_total'] >= 6 and fast_track2['bookings_over50k_running_total'] <2:
                bkreq = 2 - fast_track2['bookings_over50k_running_total']
                return "{} booking(s) left only for $50,000 Rebate.".format(bkreq)
            elif fast_track2['running_certs_total'] < 6 and fast_track2['bookings_over50k_running_total'] >=2:
                certreq= 6 - fast_track2['running_certs_total']
                return "{} certs left only for $50,000 Rebate.".format(certreq)
            elif fast_track2['running_certs_total'] < 6 and fast_track2['bookings_over50k_running_total'] <2:
                bkreq = 2 - fast_track2['bookings_over50k_running_total']
                certreq= 6 - fast_track2['running_certs_total']
                return "{} bookings and {} certs for $50,000 Rebate.".format(bkreq, certreq)
            if fast_track2['running_certs_total'] >= 6 and fast_track2['bookings_over50k_running_total'] >=2:
                return "Eligible for $50,000 Rebate"

# %%
fast_track2.loc[:, 'Old_rebate']= fast_track2.apply(f, axis=1)

# %%
fast_track2['Old_rebate']x

# %%
col = ['partner_name', 'Fast_Track_Contract', 'booking_month',
       'booking_amount', 'running_certs_total',
       #'bookings_over_50k', 'bookings_over50k_running_total',
       #'bookings_over_30k', 'bookings_over30k_running_total',
       'eligible_for_rebate', 'Old_rebate', 'PF1','PF2','contract_effective_date', 'expiration_date', 'date_fasttrack_expires',
       'AUTO_EXT_DATE', 'partner__c','PROGRAMMARKET',
       'months_remaining_FASTTRACK_eligibility']
fast_track2.loc[:, (col)]

# %%
#fast_track2.loc[fast_track2['Fast_Track_Contract']=='Old Fast Track Contract'] & fast_track2.loc[fast_track2['eligible_for_rebate']=='$30,000 Rebate']

# %%
old_ft_rebate= fast_track2.loc[fast_track2['eligible_for_rebate'].str.endswith("Rebate") & (fast_track2['Fast_Track_Contract'] == 'Old Fast Track Contract')] 
EM_rebates= old_ft_rebate.loc[old_ft_rebate['PROGRAMMARKET']=='EMERGING MARKET']
em_counts = EM_rebates['partner_name'].count()
DM_rebates= old_ft_rebate.loc[old_ft_rebate['PROGRAMMARKET']=='DEVELOPED MARKET']
dm_counts = DM_rebates['partner_name'].count()

new_ft_rebate_p1= fast_track2.loc[fast_track2['eligible_for_rebate'].str.endswith("35,000 Rebate") & (fast_track2['Fast_Track_Contract'] == 'New Fast Track Contract')] 
new_ft_rebate_p2= fast_track2.loc[fast_track2['eligible_for_rebate'].str.endswith("55,000 Rebate") & (fast_track2['Fast_Track_Contract'] == 'New Fast Track Contract')] 
p1_counts = new_ft_rebate_p1['partner_name'].count()
p2_counts = new_ft_rebate_p2['partner_name'].count()

# %%
speak("Under the Old Contract there have been {} emerging market rebates and {} developed market".format(em_counts, dm_counts))
speak("Under the New Contract there have been {} lower target rebates and {} higher target rebates".format(p1_counts, p2_counts))

# %%
total_rebates = fast_track2.loc[fast_track2['eligible_for_rebate'].str.endswith("Rebate")]
total_reb_counts= total_rebates['partner_name'].count()

# %%
close= ['CLOSE FOR PERFORMANCE TARGET 2 REBATE','CLOSE FOR PERFORMANCE TARGET 1 REBATE','CLOSE FOR EMERGING MARKET', 
       'CLOSE FOR DEVELOPED MARKET']

close_p= fast_track2.loc[fast_track2['eligible_for_rebate'].isin(close)]
close_p_counts= close_p['partner_name'].count()

# %%
col = ['partner_name', 'Fast_Track_Contract', 'booking_month',
       'booking_amount', 'running_certs_total',
       'eligible_for_rebate', 'Old_rebate', 'PF1','PF2','contract_effective_date', 'expiration_date', 'date_fasttrack_expires',
       'AUTO_EXT_DATE', 'partner__c','PROGRAMMARKET','months_remaining_FASTTRACK_eligibility']
fast_track2.loc[:, (col)]

# %% [markdown]
# # Import Sandbox Credits Data

# %%
sb = gs.open('GCP Credits script') 
sandb = sb[2]
sandb.get_as_df(has_header=True, index_colum=None, start=None, end=None, numerize=True, empty_value="")
sandbox =sandb.get_as_df(has_header=True, index_colum=None, start=None, end=None, numerize=True, empty_value="")

# %%
sandbox.columns

# %%
sandbox.loc[:,['request_type']].value_counts()

# %%
sandbox['request_type'].value_counts()

# %% [markdown]
# # RECORDER FUNCTION TESTING:

# %%
from apiclient import discovery
from httplib2 import Http
from oauth2client import file, client, tools
import base64
from email.mime.audio import MIMEAudio
from email.mime.base import MIMEBase
from email.mime.image import MIMEImage
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
import mimetypes

from datetime import datetime
from time import ctime
import time
import os
import speech_recognition as sr
import pandas as pd
import pyttsx3
import sys
import gspread
import pandas as pd
from oauth2client.service_account import ServiceAccountCredentials
import pygsheets
import pandas as pd
import webbrowser
import re
from dateutil.relativedelta import *



def send_email(orders):
    SCOPES = 'https://mail.google.com/'
    store = file.Storage('token.json')
    creds = store.get()
    if not creds or creds.invalid:
        flow = client.flow_from_clientsecrets('credentials.json', SCOPES)
        creds = tools.run_flow(flow, store)
    service = discovery.build('gmail','v1',http=creds.authorize(Http()))
    message_text = orders
    created_message = create_message('cloud-partners-incentives@google.com','malikhasan@google.com',eval(partner_sub), message_text)
    send_message(service, 'from', created_message)

#authorization
gs = pygsheets.authorize(service_account_file='My Project 1-c799865aecf9.json')
scope = ['https://spreadsheets.google.com/feeds',
         'https://www.googleapis.com/auth/drive']
credentials = ServiceAccountCredentials.from_json_keyfile_name('My Project 1-c799865aecf9.json', scope)
gc = gspread.authorize(credentials)

def p1(fast_track2):
    if fast_track2['Fast_Track_Contract']== 'New Fast Track Contract':
        if fast_track2['running_certs_total'] >= 4 and fast_track2['bookings_over30k_running_total'] <2:
            bkreq = 2 - fast_track2['bookings_over30k_running_total']
            return "{} booking(s) left only.".format(bkreq)
        elif fast_track2['running_certs_total'] < 4 or fast_track2['bookings_over30k_running_total'] <2:
            bkreq = 2 - fast_track2['bookings_over30k_running_total']
            certreq= 4 - fast_track2['running_certs_total']
            return "{} bookings left and {} certs.".format(bkreq, certreq)
        if fast_track2['running_certs_total'] >= 4 and fast_track2['bookings_over30k_running_total'] >=2:
            return "$35,000 Rebate" 
        
        
def p2(fast_track2):
    if fast_track2['Fast_Track_Contract']== 'New Fast Track Contract':
        if fast_track2['running_certs_total'] >= 6 and fast_track2['bookings_over50k_running_total'] <2:
            bkreq = 2 - fast_track2['bookings_over50k_running_total']
            return "{} booking(s) left only.".format(bkreq)
        elif fast_track2['running_certs_total'] < 6 or fast_track2['bookings_over50k_running_total'] <2:
            bkreq = 2 - fast_track2['bookings_over50k_running_total']
            certreq= 6 - fast_track2['running_certs_total']
            return "{} bookings left and {} certs.".format(bkreq, certreq)
        if fast_track2['running_certs_total'] >= 6 and fast_track2['bookings_over50k_running_total'] >=2:
            return "$55,000 Rebate"                 
        
def f(fast_track2):
    if fast_track2['Fast_Track_Contract']== 'Old Fast Track Contract':
        if fast_track2['PROGRAMMARKET']== 'EMERGING MARKET':
            
            if fast_track2['running_certs_total'] >= 6 and fast_track2['bookings_over30k_running_total'] <2:
                bkreq = 2 - fast_track2['bookings_over30k_running_total']
                return "{} booking(s) left only for $30,000 Rebate.".format(bkreq)
            elif fast_track2['running_certs_total'] < 6 or fast_track2['bookings_over30k_running_total'] <2:
                bkreq = 2 - fast_track2['bookings_over30k_running_total']
                certreq= 6 - fast_track2['running_certs_total']
                return "{} bookings and {} certs $30,000 Rebate.".format(bkreq, certreq)
            if fast_track2['running_certs_total'] >= 6 and fast_track2['bookings_over30k_running_total'] >=2:
                return "Eligible for $30,000 Rebate"       
        if fast_track2['PROGRAMMARKET']== 'DEVELOPED MARKET':
            if fast_track2['running_certs_total'] >= 6 and fast_track2['bookings_over50k_running_total'] <2:
                bkreq = 2 - fast_track2['bookings_over50k_running_total']
                return "{} booking(s) left only for $50,000 Rebate.".format(bkreq)
            elif fast_track2['running_certs_total'] < 6 and fast_track2['bookings_over50k_running_total'] >=2:
                certreq= 6 - fast_track2['running_certs_total']
                return "{} certs left only for $50,000 Rebate.".format(certreq)
            elif fast_track2['running_certs_total'] < 6 and fast_track2['bookings_over50k_running_total'] <2:
                bkreq = 2 - fast_track2['bookings_over50k_running_total']
                certreq= 6 - fast_track2['running_certs_total']
                return "{} bookings and {} certs for $50,000 Rebate.".format(bkreq, certreq)
            if fast_track2['running_certs_total'] >= 6 and fast_track2['bookings_over50k_running_total'] >=2:
                return "Eligible for $50,000 Rebate"
#_____________________________________________________________________________________________________________________________________________________________________________________
#r.recognize_google(audio, key= 'AIzaSyAdTyq2lSSoinplSa-O1g1syZhhaPgUu1Y'))
def speak(audioString):
    print(audioString)
    engine = pyttsx3.init()
    engine.setProperty('voice', 'com.apple.speech.synthesis.voice.daniel')
    engine.say(audioString)
    engine.runAndWait()

def recorder():
    months = ['January', 'February','March','April', 'May', 'June', 'July','August','September','October','November','December','all', 'All', 'sandbox','update','Update']
    currentMonth = datetime.now().strftime('%B')
    programs = ['deal reg', 'fast track', 'sandbox','sandbox credits dashboard','sandbox credits','credits dashboard', 'the sandbox', 'track report']
    engine = pyttsx3.init()
    engine.setProperty('voice', 'com.apple.speech.synthesis.voice.daniel')
    
    r = sr.Recognizer()
    with sr.Microphone() as source:   
        r.adjust_for_ambient_noise(source)
        audio = r.listen(source)
        r.recognize_google(audio, key= 'AIzaSyAdTyq2lSSoinplSa-O1g1syZhhaPgUu1Y')
        
    try:
        response = r.recognize_google(audio, key= 'AIzaSyAdTyq2lSSoinplSa-O1g1syZhhaPgUu1Y')
        regex = re.compile(r'(?=(.))(?:deal dredge|deer ridge|deodorant|Diehl dredge|eldridge|derege|deals ridge|Delridge|dieldrin|dealer edge|doddridge|deal ridge|deel ridge)', flags=re.IGNORECASE)
        response = regex.sub('deal reg', response)
        regex = re.compile(r'(?=(.))(?:fastrak|fat track|fat rack)', flags=re.IGNORECASE)
        response = regex.sub('fast track', response)
        regex = re.compile(r'(?=(.))(?:current|present|todays|this month|this months)', flags=re.IGNORECASE)
        currentMonth = datetime.now().strftime('%B')
        response = regex.sub(currentMonth, response)
        #response = r.recognize_google(audio, key= 'AIzaSyAdTyq2lSSoinplSa-O1g1syZhhaPgUu1Y').replace('deal dredge', 'deal reg')
        #response = r.recognize_google(audio, key= 'AIzaSyAdTyq2lSSoinplSa-O1g1syZhhaPgUu1Y').replace('deer ridge', 'deal reg')
        #response = response.replace('FasTrak', 'fast track')
        endit =re.search(r"\bno\b|stop|thanks|fine|not|nope|exit|end|quit", response, re.IGNORECASE)
        month_found = [word for word in response.split() if word in months]
        program_found = []
        regexes = [re.compile(p, re.I) for p in programs]
        program_found = [regex.pattern for regex in regexes if regex.search(response)]
####################################################################################################################################
        if endit:
            print("{} : {}".format(your_name, response))
            engine.say('It has been a pleasure assisting you {}'.format(your_name)) 
            engine.runAndWait()
            print("Stem: It has been a pleasure assisting you {}".format(your_name))
            global running
            running = False
            speak('Before you go, would you like to see any additional documentation on any of the programs?')
            while True:
                try:
                    with sr.Microphone() as source:
                        r.adjust_for_ambient_noise(source)
                        rep = r.listen(source)
                        r.recognize_google(rep, key= 'AIzaSyAdTyq2lSSoinplSa-O1g1syZhhaPgUu1Y')
                        answer= r.recognize_google(rep, key= 'AIzaSyAdTyq2lSSoinplSa-O1g1syZhhaPgUu1Y')
                        print("{} said: {}".format(your_name, answer))
                        match =re.search(r"\bno\b|stop|thanks|fine|not|dont think", answer, re.IGNORECASE)
                        match2 =re.search(r"yes|sure|ok|okay|yeah|why not", answer, re.IGNORECASE)
                except sr.UnknownValueError:
                    speak("Sorry I do not understand, please say that again")
                    continue
                
                else:
                    if match2:
                        var=input('Please type in the Program: ')
                        var= var.lower()
                        engine.say("Goodbye {}".format(your_name))
                        engine.runAndWait()
                        if var=='fast track':
                            webbrowser.open('https://www.cloudconnect.goog/docs/DOC-19904')
                        elif var =='deal reg':
                            webbrowser.open('https://www.cloudconnect.goog/docs/DOC-24336')
                        elif var == 'psf' or 'partner services fund':
                            webbrowser.open('https://www.cloudconnect.goog/docs/DOC-19870')
                        elif var in ('sandbox', 'sandbox credits'):
                            webbrowser.open('https://www.cloudconnect.goog/docs/DOC-16822')
                        else:
                            webbrowser.open('https://www.cloudconnect.goog/search.jspa?q={}'.format(var))
                    if match:
                        speak("Goodbye {}".format(your_name))
                break
####################################################################################################################################
        elif month_found == [] and program_found == []:
            print("{} : {}".format(your_name, response))
            engine.say("Please specify a valid request {}".format(your_name))
            engine.runAndWait()
            print("Please specify a valid request {}".format(your_name))
            
          
        elif month_found == [] and program_found != []:
            print("{} : {}".format(your_name, response))
            engine.say("Please specify a valid request for {}".format(program_found[0]))
            engine.runAndWait()
            print("{} did not specify a valid request for {}".format(your_name,program_found[0]))
          
        
        elif month_found != [] and program_found == []:
            print("{} : {}".format(your_name, response))
            engine.say("Please specify a valid program?")
            engine.runAndWait()
            print("Please specify a valid program {}".format(your_name))
           
        
        #else:
            #print("{}'s question: {}".format(your_name, response))
            
            
    except sr.UnknownValueError:
        #print("Google Speech Recognition could not understand audio")
        speak("Google Speech Recognition could not understand audio")
    except sr.RequestError as e:
        print("Could not request results from Google Speech Recognition service; {0}".format(e))
        speak("There was an unknown error, sorry, I am still learning")
    
    else:
        months2 = ['January', 'February','March','April', 'May', 'June', 'July','August','September','October','November','December']#,'present','current']
        for mon,prog in zip(month_found, program_found):
            if mon in months2 and 'deal reg' in program_found and "rebates" in response:
                print('{}: {}'.format(your_name, response))
                speak("Here are the Deal Reg rebates for {}".format(mon))
                gs = pygsheets.authorize(service_account_file='My Project 1-c799865aecf9.json')
                you = gs.open('Example') 
                youzz = you[10]
                youzz.get_as_df(has_header=True, index_colum=None, start=None, end=None, numerize=True, empty_value="")
                bookings =youzz.get_as_df(has_header=True, index_colum=None, start=None, end=None, numerize=True, empty_value="")  
                bookings.loc[:, 'New_Rebate']= pd.to_numeric(bookings['New_Rebate'], downcast='float')
                bookings = bookings.loc[(bookings['New_Rebate'] >= .01)].copy()
                monthly_rebates = bookings.loc[bookings['Booking Month'].isin(month_found)].copy()
                rebates_count = monthly_rebates['New_Rebate'].nunique()
                speak("there were {} rebates for the month of {}.".format(rebates_count, mon))
                column_names = ['Name','Partner_Name SFDC','Booking Date','Booking Month', 'New_Rebate','Running_Rebate','Running_Total']
                monthly_rebates =monthly_rebates.loc[:, column_names]
                display(monthly_rebates)
                speak("Would you like to export this data into a new or existing Google Sheet?")
                with sr.Microphone() as source:
                    r.adjust_for_ambient_noise(source)
                    rep = r.listen(source)
                    r.recognize_google(rep, key= 'AIzaSyAdTyq2lSSoinplSa-O1g1syZhhaPgUu1Y')
                    answer= r.recognize_google(rep, key= 'AIzaSyAdTyq2lSSoinplSa-O1g1syZhhaPgUu1Y')
                    print('{}s response: {}'.format(your_name, answer))
                    reply1 =re.search(r"yes|sure|ok|okay|yeah|would love|love to|absolutely|ofcourse", answer, re.IGNORECASE)
                    reply2 =re.search(r"no|stop|nah|im okay|not|nevermind|nope", answer, re.IGNORECASE)
                    if reply1:
                        file = input('Please Name your excel file')
                        filename= file + '.xlsx'
                        writer = pd.ExcelWriter(filename)
                        monthly_rebates.to_excel(writer,'Sheet1')
                        writer.save()
                    if reply2:
                        speak("kk then")
                        
                speak('Would you like to email this report to yourself or a colleague?')
                with sr.Microphone() as source:
                    r.adjust_for_ambient_noise(source)
                    rep = r.listen(source)
                    r.recognize_google(rep ,key= 'AIzaSyAdTyq2lSSoinplSa-O1g1syZhhaPgUu1Y')
                    answer= r.recognize_google(rep ,key= 'AIzaSyAdTyq2lSSoinplSa-O1g1syZhhaPgUu1Y')
                    print('{}s response: {}'.format(your_name, answer))
                    rep1 =re.search(r"yes|sure|ok|okay|yeah|would love|love to|absolutely|ofcourse", answer, re.IGNORECASE)
                    rep2 =re.search(r"no|stop|nah|im okay|not|nevermind|nope", answer, re.IGNORECASE)
                    if rep1:
                        gs = pygsheets.authorize(service_account_file='My Project 1-c799865aecf9.json')
                        sh = gs.open('Example')
                        email = input('Please enter the email address: ')
                        sh.share(email)
                        print("Sent to: {}".format(email))
                    if rep2:
                        speak("OK then")
            
            if mon in months2 and 'deal reg' in program_found and "bookings" in response:
                print('{}: {}'.format(your_name, response))
                print('Stem: Here are the deal reg bookings for {}'.format(mon))
                speak("I understand you want to see Deal Reg bookings for {}, here they are".format(mon))
                mon= mon.replace('present', currentMonth)
                mon=mon.replace('current', currentMonth)
                gs = pygsheets.authorize(service_account_file='My Project 1-c799865aecf9.json')
                dr = gs.open('Example') 
                drr = dr[10]
                drr.get_as_df(has_header=True, index_colum=None, start=None, end=None, numerize=True, empty_value="")
                bookings =drr.get_as_df(has_header=True, index_colum=None, start=None, end=None, numerize=True, empty_value="")
                monthly_bookings = bookings.loc[bookings['Booking Month'].isin(month_found)].copy()
                #month_bookings= bookings[bookings.bookingmonth==mon]
                bk_counts=monthly_bookings['Booking G Suite'].count()
                partner_counts=monthly_bookings['Partner_Name SFDC'].nunique()
                reb= [i for i in monthly_bookings['New_Rebate'].unique() if i >= .01]
                current_date= (datetime.now().strftime("%d %B %Y"))
                speak("{} currently has {} bookings from {} partners and {} eligible rebates.".format(mon, bk_counts, partner_counts, len(reb)))
                display(monthly_bookings.iloc[:, 0:15])
                speak('Would you like to export this data into a new Google Spreadsheet?')
                with sr.Microphone() as source:
                    r.adjust_for_ambient_noise(source)
                    rep = r.listen(source)
                    r.recognize_google(rep ,key= 'AIzaSyAdTyq2lSSoinplSa-O1g1syZhhaPgUu1Y')
                    answer= r.recognize_google(rep ,key= 'AIzaSyAdTyq2lSSoinplSa-O1g1syZhhaPgUu1Y')
                    print('{}s response: {}'.format(your_name, answer))
                    rep =re.search(r"yes|sure|ok|okay|yeah|would love|love to|absolutely|ofcourse", answer, re.IGNORECASE)
                    rep0 =re.search(r"no|stop|nah|im okay|not|nevermind|nope", answer, re.IGNORECASE)
                    if rep:
                        file = input('Please Name your excel file')
                        filename= file + '.xlsx'
                        writer = pd.ExcelWriter(filename)
                        monthly_bookings.to_excel(writer,'Sheet1')
                        writer.save()
                    if rep0:
                        speak("kk then")
                
                speak('Would you like to email this report to yourself or a colleague?')
                with sr.Microphone() as source:
                    r.adjust_for_ambient_noise(source)
                    rep = r.listen(source)
                    r.recognize_google(rep ,key= 'AIzaSyAdTyq2lSSoinplSa-O1g1syZhhaPgUu1Y')
                    answer= r.recognize_google(rep ,key= 'AIzaSyAdTyq2lSSoinplSa-O1g1syZhhaPgUu1Y')
                    print('{}s response: {}'.format(your_name, answer))
                    repo =re.search(r"yes|sure|ok|okay|yeah|would love|love to|absolutely|ofcourse", answer, re.IGNORECASE)
                    repo2 =re.search(r"no|stop|nah|im okay|not|nevermind|nope", answer, re.IGNORECASE)
                    if repo:
                        gs = pygsheets.authorize(service_account_file='My Project 1-c799865aecf9.json')
                        sh = gs.open('Example')
                        email = input('Please enter the email address: ')
                        sh.share(email)
                        print("Sent to: {}".format(email))
                    if repo2:
                        speak("OK then")
                              
            if 'deal reg' in program_found and mon in ('all' or 'All') in response:
                print('{}: {}'.format(your_name, response))
                if 'rebates' in response.lower():
                    speak("OK, pulling up the accumulative Deal Reg Report")
                    print("Stem: OK, pulling up the accumulative Deal Reg Report")
                    gs = pygsheets.authorize(service_account_file='My Project 1-c799865aecf9.json')
                    dr = gs.open('Example')
                    trial = dr[7]##Copy of Deal Reg Payout tab
                    dr_trix=trial.get_as_df(has_header=True, index_colum=None, start=None, end=None, numerize=True, empty_value="")
                    DR_copy= dr_trix.loc[:, 'Booking Month':'Running_Total']
                    DR_copy.index
                    book = dr[6]########skU-bookings
                    booking=book.get_as_df(has_header=True, index_colum=None, start=None, end=None, numerize=True, empty_value="")
                    booker=booking.loc[:, 'Booking Month':'Running_Total']
                    common = pd.merge(booker, DR_copy, how='inner')
                    df1 = pd.merge(booker, DR_copy, indicator=True, how='outer')
                    only_BK =df1[df1.loc[:, '_merge']=='left_only'].reset_index(drop=True)
                    only_DR =df1[df1.loc[:, '_merge']=='right_only'].reset_index(drop=True)
                    only_BK= only_BK.iloc[:, :-1]
                    only_DR= only_DR.iloc[:, :-1]
                    #Bookings ARE NOT from deal reg tracker opptys: Can think of these as NEW opptys to be added
                    only_BK.loc[:, 'Booking G Suite']= pd.to_numeric(only_BK['Booking G Suite'], downcast='float')
                    #only_BK[~only_BK['Name'].isin(only_DR['Name'])] | [only_BK['Booking G Suite']>0]
                    guess = only_BK[~only_BK['Name'].isin(only_DR['Name'])]
                    guess1= guess.loc[(guess['Booking G Suite'] > 0)]
                    #BOOKINGS THAT ARE IN OPPTY's in DEAL reg Tracker: THink of these as deals to be added to opptys already in the tracker
                    new_existing= only_BK.loc[(only_BK['Booking G Suite'] >0 ) & only_BK['Name'].isin(only_DR['Name'])]
                    result = pd.concat([guess1, new_existing, DR_copy], ignore_index=True)
                    cols =[]
                    for col in result.columns:
                        if col != 'Rebate Payout at G Suite (paid monthly)':
                            cols.append(col)
                    result = pd.merge(result, dr_trix, how='left', on=cols)
                    result= result.drop(columns=['Type of Opportunity? (New/Upsell/etc)', 'Opportunity Creation Date','Q2 Booking reported in May 18 (incorrect)','Over/(Under) paid','Q2 rebate reported in May 18 (incorrect)'])
                    result= result.sort_values(by=['Name', 'Booking Date'])
                    result['Running_Total'] = result.groupby('Name')['Booking G Suite'].transform(lambda g: g.cumsum())
                    
                    result.loc[:,'Booking Date'] = pd.to_datetime(result['Booking Date'])
                    result['Rebate Exp Date']=result.groupby(['Name'])['Booking Date'].transform(lambda x: x.min()+ relativedelta(years=+1))

                    runrebate= result['Running_Total'].apply(lambda x: x *.06 if x >= 18000 else 0)
                    result.insert(loc=12, column='Running_Rebate', value=runrebate)

                    newrebates=result.groupby(['Name'])['Running_Rebate'].transform(lambda x: x- x.shift(1))
                    result.insert(loc=11, column='New_Rebate', value=newrebates)
                    result['New_Rebate']= result['New_Rebate'].fillna(result['Running_Rebate'])
                    
                    rebate_counts =result[result["New_Rebate"]>0].nunique()["New_Rebate"]
                    sliced= result.iloc[:, 0:19].copy()
                    rebs= (sliced["Running_Rebate"] > 0)
                    reba= sliced[rebs]
                    pivot= pd.pivot_table(result, index= ['Partner_Name SFDC', "Name"], values= ['New_Rebate','Booking G Suite'], aggfunc= 'sum', fill_value= 0,
                    margins = True, margins_name= 'Grand Total')
                    current_date= (datetime.now().strftime("%d %B %Y"))
                    partner_counts=reba['Partner_Name SFDC'].nunique()
                    total_rebates= round(result['New_Rebate'].sum())
                    speak("As of {} there have been {} rebates totalling {} for {} partners".format(current_date, rebate_counts,total_rebates ,partner_counts))
                    display(pivot)
                    speak('Would you like to email this report to yourself or a colleague?')
#------------------------------------------------------------------------------------------------------------------------------------------------------------                    
                    while True:
                        try:
                            with sr.Microphone() as source:
                                r.adjust_for_ambient_noise(source)
                                rep = r.listen(source)
                                r.recognize_google(rep ,key= 'AIzaSyAdTyq2lSSoinplSa-O1g1syZhhaPgUu1Y')
                                answer= r.recognize_google(rep ,key= 'AIzaSyAdTyq2lSSoinplSa-O1g1syZhhaPgUu1Y')
                                rep1 =re.search(r"yes|sure|ok|okay|yeah|would love|love to|absolutely|ofcourse", answer, re.IGNORECASE)
                                rep2 =re.search(r"no|stop|nah|im okay|not|nevermind|nope", answer, re.IGNORECASE)
                        except sr.UnknownValueError:
                            speak('Please Say Yes or No')
                            continue 
                        else:
                            if rep1:
                                gs = pygsheets.authorize(service_account_file='My Project 1-c799865aecf9.json')
                                sh = gs.open('Example')
                                email = input('Please enter the email address: ')
                                sh.share(email)
                            if rep2:
                                speak("OK then")  
                            else:
                                speak("we Seem to be having difficulty, lets move on")
                        break
                        
                    speak('Would you like to export this data into a new Google Spreadsheet?')
                    while True:
                        try:
                            with sr.Microphone() as source:
                                r.adjust_for_ambient_noise(source)
                                rep = r.listen(source)
                                r.recognize_google(rep ,key= 'AIzaSyAdTyq2lSSoinplSa-O1g1syZhhaPgUu1Y')
                                answer= r.recognize_google(rep ,key= 'AIzaSyAdTyq2lSSoinplSa-O1g1syZhhaPgUu1Y')
                                print('{}s response: {}'.format(your_name, answer))
                                rep =re.search(r"yes|sure|ok|okay|yeah|would love|love to|absolutely|ofcourse", answer, re.IGNORECASE)
                                rep0 =re.search(r"no|stop|nah|im okay|not|nevermind|nope", answer, re.IGNORECASE)
                        except sr.UnknownValueError:
                            speak('Please say Yes or No')
                            continue
                        else:
                            if rep:
                                file = input('Please Name your excel file')
                                filename= file + '.xlsx'
                                writer = pd.ExcelWriter(filename)
                                result.to_excel(writer,'Sheet1')
                                writer.save()
                            if rep0:
                                speak("kk then")
                            else:
                                speak('Lets move on')
                        break
#-------------------------------------------------------------------------------------------------------------------------------------------------------------------------                                    
                            
                if 'bookings' in response.lower():
                    print('{}: {}'.format(your_name, response))
                    speak("OK, pulling up all bookings for Deal Reg")
                    print("Stem: OK, pulling up all bookings for Deal Reg")
                    gs = pygsheets.authorize(service_account_file='My Project 1-c799865aecf9.json')
                    dr = gs.open('Example')
                    trial = dr[7]##Copy of Deal Reg Payout tab
                    dr_trix=trial.get_as_df(has_header=True, index_colum=None, start=None, end=None, numerize=True, empty_value="")
                    DR_copy= dr_trix.loc[:, 'Booking Month':'Running_Total']
                    DR_copy.index
                    book = dr[6]########skU-bookings
                    booking=book.get_as_df(has_header=True, index_colum=None, start=None, end=None, numerize=True, empty_value="")
                    booking
                    booker=booking.loc[:, 'Booking Month':'Running_Total']
                    common = pd.merge(booker, DR_copy, how='inner')
                    df1 = pd.merge(booker, DR_copy, indicator=True, how='outer')
                    only_BK =df1[df1.loc[:, '_merge']=='left_only'].reset_index(drop=True)
                    only_DR =df1[df1.loc[:, '_merge']=='right_only'].reset_index(drop=True)
                    only_BK= only_BK.iloc[:, :-1]
                    only_DR= only_DR.iloc[:, :-1]
                    #Bookings ARE NOT from deal reg tracker opptys: Can think of these as NEW opptys to be added
                    only_BK.loc[:, 'Booking G Suite']= pd.to_numeric(only_BK['Booking G Suite'], downcast='float')
                    #only_BK[~only_BK['Name'].isin(only_DR['Name'])] | [only_BK['Booking G Suite']>0]
                    guess = only_BK[~only_BK['Name'].isin(only_DR['Name'])]
                    guess1= guess.loc[(guess['Booking G Suite'] > 0)]
                    #BOOKINGS THAT ARE IN OPPTY's in DEAL reg Tracker: THink of these as deals to be added to opptys already in the tracker
                    new_existing= only_BK.loc[(only_BK['Booking G Suite'] >0 ) & only_BK['Name'].isin(only_DR['Name'])]
                    result = pd.concat([guess1, new_existing, DR_copy], ignore_index=True)
                    cols =[]
                    for col in result.columns:
                        if col != 'Rebate Payout at G Suite (paid monthly)':
                            cols.append(col)
                    result = pd.merge(result, dr_trix, how='left', on=cols)
                    #result.loc[:, 'Running_Total']= pd.to_numeric(result['Running_Total'], downcast='float')
                    result['Running_Total'] = result.groupby('Name')['Booking G Suite'].transform(lambda g: g.cumsum())
                    
                    newrebate= result.groupby('Name')['Booking G Suite'].transform(lambda x: x *.06 if x[:].sum() >= 18000 else 0)
                    rebatesrun= result.groupby('Name')['Running_Total'].transform(lambda x: x *.06 if x.iat[-1] >= 18000 and x.iat[0]>=18000 else (x*.06 if x.iat[-1] >= 18000  else 0))
                    result.loc[:, 'Total Rebate Earned']= result.groupby('Name')['Running_Total'].transform(lambda x: x.iat[-1]*.06 if x.iat[-1] >= 18000 else 0)
                    result.insert(loc=15, column='New Rebate Payout at G Suite (paid monthly)', value=newrebate)
                    result.insert(loc=16, column='Rebates(Runnning)', value=rebatesrun)

                    #rebate_counts =result[result["Total Rebate Earned"]>0].nunique()["Total Rebate Earned"]
                    sliced= result.iloc[:, 0:19].copy()
                    deal_counts=result['Name'].nunique()
                    partner_counts=result['Partner_Name SFDC'].nunique()
                    sliced= sliced.sort_values(by=['Name', 'Booking Date'])
                    grandtotal=round(sliced['Booking G Suite'].sum())
                    current_date= (datetime.now().strftime("%d %B %Y"))
                    speak("As of {} there has been a total of {} bookings for {} partners and {} deals".format(current_date, grandtotal, partner_counts,deal_counts))
                    display(sliced)
                    speak('Would you like to email this report to yourself or a colleague?')
                    while True:
                        try:
                            with sr.Microphone() as source:
                                r.adjust_for_ambient_noise(source)
                                rep = r.listen(source)
                                r.recognize_google(rep ,key= 'AIzaSyAdTyq2lSSoinplSa-O1g1syZhhaPgUu1Y')
                                answer= r.recognize_google(rep ,key= 'AIzaSyAdTyq2lSSoinplSa-O1g1syZhhaPgUu1Y')
                                rep1 =re.search(r"yes|sure|ok|okay|yeah|would love|love to|absolutely|ofcourse", answer, re.IGNORECASE)
                                rep2 =re.search(r"no|stop|nah|im okay|not|nevermind|nope", answer, re.IGNORECASE)
                        except sr.UnknownValueError:
                            speak('Please Say Yes or No')
                            continue 
                        else:
                            if rep1:
                                gs = pygsheets.authorize(service_account_file='My Project 1-c799865aecf9.json')
                                sh = gs.open('Example')
                                email = input('Please enter the email address: ')
                                sh.share(email)
                            if rep2:
                                speak("OK then")  
                            else:
                                speak("we Seem to be having difficulty, lets move on")
                        break
                    
                    speak('Would you like to export this data into a new Google Spreadsheet?')
                    while True:
                        try:
                            with sr.Microphone() as source:
                                r.adjust_for_ambient_noise(source)
                                rep = r.listen(source)
                                r.recognize_google(rep ,key= 'AIzaSyAdTyq2lSSoinplSa-O1g1syZhhaPgUu1Y')
                                answer= r.recognize_google(rep ,key= 'AIzaSyAdTyq2lSSoinplSa-O1g1syZhhaPgUu1Y')
                                print('{}s response: {}'.format(your_name, answer))
                                rep =re.search(r"yes|sure|ok|okay|yeah|would love|love to|absolutely|ofcourse", answer, re.IGNORECASE)
                                rep0 =re.search(r"no|stop|nah|im okay|not|nevermind|nope", answer, re.IGNORECASE)
                        except sr.UnknownValueError:
                            speak('Please say Yes or No')
                            continue
                        else:
                            if rep:
                                file = input('Please Name your excel file')
                                filename= file + '.xlsx'
                                writer = pd.ExcelWriter(filename)
                                sliced.to_excel(writer,'Sheet1')
                                writer.save()
                            if rep0:
                                speak("kk then")
                            else:
                                speak('Lets move on')
                        break
#---------------------------------------------------------------------------------------------------------------------------------------------------------------------------             
            
            if "fast track" in prog and "rebates" in response:
                print('{}: {}'.format(your_name, response))
                current_date= (datetime.now().strftime("%d %B %Y"))
                print('Stem: Here are all the rebates for for Fast Track')
                speak("Here are the rebates for Fast Track")
                gs = pygsheets.authorize(service_account_file='My Project 1-c799865aecf9.json')
                scope = ['https://spreadsheets.google.com/feeds','https://www.googleapis.com/auth/drive']
                fa = gs.open('GCP Fast Track - Tracker') 
                ftt2 = fa[3]
                ftt2.get_as_df(has_header=True, index_colum=None, start=None, end=None, numerize=True, empty_value="")
                fast_track2 =ftt2.get_as_df(has_header=True, index_colum=None, start=None, end=None, numerize=True, empty_value="")
                fast_track2.loc[:, 'PF1']= fast_track2.apply(p1, axis=1)
                fast_track2.loc[:, 'PF2']=fast_track2.apply(p2, axis=1)
                fast_track2.loc[:, 'Old_rebate']= fast_track2.apply(f, axis=1)
                old_ft_rebate= fast_track2.loc[fast_track2['eligible_for_rebate'].str.endswith("Rebate") & (fast_track2['Fast_Track_Contract'] == 'Old Fast Track Contract')] 
                EM_rebates= old_ft_rebate.loc[old_ft_rebate['PROGRAMMARKET']=='EMERGING MARKET']
                em_counts = EM_rebates['partner_name'].count()
                DM_rebates= old_ft_rebate.loc[old_ft_rebate['PROGRAMMARKET']=='DEVELOPED MARKET']
                dm_counts = DM_rebates['partner_name'].count()
                new_ft_rebate_p1= fast_track2.loc[fast_track2['eligible_for_rebate'].str.endswith("35,000 Rebate") & (fast_track2['Fast_Track_Contract'] == 'New Fast Track Contract')] 
                new_ft_rebate_p2= fast_track2.loc[fast_track2['eligible_for_rebate'].str.endswith("55,000 Rebate") & (fast_track2['Fast_Track_Contract'] == 'New Fast Track Contract')] 
                p1_counts = new_ft_rebate_p1['partner_name'].count()
                p2_counts = new_ft_rebate_p2['partner_name'].count()
                close= ['CLOSE FOR PERFORMANCE TARGET 2 REBATE','CLOSE FOR PERFORMANCE TARGET 1 REBATE','CLOSE FOR EMERGING MARKET', 
               'CLOSE FOR DEVELOPED MARKET']
                close_p= fast_track2.loc[fast_track2['eligible_for_rebate'].isin(close)]
                close_p_counts= close_p['partner_name'].count()
                total_rebates = fast_track2.loc[fast_track2['eligible_for_rebate'].str.endswith("Rebate")]
                total_reb_counts= total_rebates['partner_name'].count()
                speak("Under the Old Contract there have been {} emerging market rebates and {} developed market".format(em_counts, dm_counts))
                speak("Under the New Contract there have been {} lower target rebates and {} higher target rebates".format(p1_counts, p2_counts))
                speak("As of {} there have been {} rebates while {} partners are close to achieving a rebate".format(current_date, total_reb_counts, close_p_counts))
                display(total_rebates)
                speak("Would you like to see all the data for Fast Track?")
                with sr.Microphone() as source:
                    r.adjust_for_ambient_noise(source)
                    rep = r.listen(source)
                    r.recognize_google(rep ,key= 'AIzaSyAdTyq2lSSoinplSa-O1g1syZhhaPgUu1Y')
                    answer= r.recognize_google(rep ,key= 'AIzaSyAdTyq2lSSoinplSa-O1g1syZhhaPgUu1Y')
                    print('{}s response: {}'.format(your_name, answer))
                    repp =re.search(r"yes|sure|ok|okay|yeah|would love|love to|absolutely|ofcourse", answer, re.IGNORECASE)
                    rept =re.search(r"no|stop|nah|im okay|not|nevermind|nope", answer, re.IGNORECASE)
                    
                    if repp:
                        col = ['partner_name', 'Fast_Track_Contract', 'booking_month','booking_amount', 'running_certs_total',
                           'eligible_for_rebate', 'Old_rebate', 'PF1','PF2','contract_effective_date', 
                           'expiration_date', 'date_fasttrack_expires','AUTO_EXT_DATE', 'partner__c','PROGRAMMARKET','months_remaining_FASTTRACK_eligibility']
                        ft10=fast_track2.loc[:, (col)]
                        print(ft10)
                    if rept:
                        speak("Ok then")
                
                speak('Would you like to email this report to yourself or a colleague?')
                with sr.Microphone() as source:
                    r.adjust_for_ambient_noise(source)
                    rep = r.listen(source)
                    r.recognize_google(rep , key= 'AIzaSyAdTyq2lSSoinplSa-O1g1syZhhaPgUu1Y')
                    answer= r.recognize_google(rep, key= 'AIzaSyAdTyq2lSSoinplSa-O1g1syZhhaPgUu1Y')
                    print('{}s response: {}'.format(your_name, answer))
                    rep4 =re.search(r"yes|sure|ok|okay|yeah|would love|love to|absolutely|ofcourse", answer, re.IGNORECASE)
                    rep5 =re.search(r"no|stop|nah|im okay|not|nevermind|nope", answer, re.IGNORECASE)
                    
                    if rep4:
                        gs = pygsheets.authorize(service_account_file='My Project 1-c799865aecf9.json')
                        sh = gs.open('GCP Fast Track - Tracker')
                        email = input('Please enter the email address: ')
                        sh.share(email)
                        print("Sent to {}".format(email))
                    if rep5:
                        speak("OK then")          
                        
            if ('sandbox credits dashboard' or 'credits dashboard' or 'sandbox dashboard') in response:
                print("{}: {}".format(your_name, response))
                speak('Opening the Sandbox Credits dashboard in an external browser')
                webbrowser.open('https://datastudio.google.com/c/u/0/reporting/12E9YhOW0cIqk8qpOqts46K9KQeu97V_N/page/T3gG')
                        
            if "fast track" in prog and "update" in response:
                print('{}: {}'.format(your_name, response))
                current_date= (datetime.now().strftime("%d %B %Y"))
                speak("Please confirm you want to update the Fast Track Tracker")
                confirm = str(input("Enter yes/no "))
                copy = str(input("Do you want to create a copy of the current version? Enter yes/no"))
                if confirm == "yes" and copy =="no":
                    gs = pygsheets.authorize(service_account_file='My Project 1-c799865aecf9.json')
                    scope = ['https://spreadsheets.google.com/feeds','https://www.googleapis.com/auth/drive']
                    fa = gs.open('GCP Fast Track - Tracker') 
                    ftt2 = fa[3]
                    ftt2.get_as_df(has_header=True, index_colum=None, start=None, end=None, numerize=True, empty_value="")
                    fast_track2 =ftt2.get_as_df(has_header=True, index_colum=None, start=None, end=None, numerize=True, empty_value="")
                    fast_track2.loc[:, 'PF1']= fast_track2.apply(p1, axis=1)
                    fast_track2.loc[:, 'PF2']=fast_track2.apply(p2, axis=1)
                    fast_track2.loc[:, 'Old_rebate']= fast_track2.apply(f, axis=1)
                    #fast_track2.loc[:, 'Emailed']=
                    ##Update fast track tracker
                    ftt2.set_dataframe(fast_track2, start='A1' ,copy_index=True, copy_head= True, fit=True)
                    speak("The Fast Track Tracker has been updated")
                elif confirm=="yes" and copy =="yes":
                    ####this part creates a copy of combined worksheet
                    gs = pygsheets.authorize(service_account_file='My Project 1-c799865aecf9.json')
                    scope = ['https://spreadsheets.google.com/feeds','https://www.googleapis.com/auth/drive']
                    fa = gs.open('GCP Fast Track - Tracker') 
                    wks = fa.add_worksheet("copy of Combined", src_worksheet=sh.worksheet_by_title("Combined"))
                    print("Fast Track Tracker copy was successfuly created")
                    ###this part updated combined
                    ftt2 = fa[3]
                    ftt2.get_as_df(has_header=True, index_colum=None, start=None, end=None, numerize=True, empty_value="")
                    fast_track2 =ftt2.get_as_df(has_header=True, index_colum=None, start=None, end=None, numerize=True, empty_value="")
                    fast_track2.loc[:, 'PF1']= fast_track2.apply(p1, axis=1)
                    fast_track2.loc[:, 'PF2']=fast_track2.apply(p2, axis=1)
                    fast_track2.loc[:, 'Old_rebate']= fast_track2.apply(f, axis=1)
                    ##Update fast track tracker- updated Combined worksheet
                    ftt2.set_dataframe(fast_track2, start='A1' ,copy_index=True, copy_head= True, fit=True)
                    speak("The Fast Track Tracker has been updated and a copy has been saved ")
                else:
                    speak("No confirmation was provided for this request".format(your_name))
                
                speak("Would you like to check to see if Partners are close or eligible for rebate?") 
                
                confirm = str(input("Enter yes/no"))
                if confirm =="yes":
                    #print(confirm)
                    gs = pygsheets.authorize(service_account_file='My Project 1-c799865aecf9.json')
                    scope = ['https://spreadsheets.google.com/feeds','https://www.googleapis.com/auth/drive']
                    fa = gs.open('GCP Fast Track - Tracker') 
                    ftt2 = fa[3]
                    ftt2.get_as_df(has_header=True, index_colum=None, start=None, end=None, numerize=True, empty_value="")
                    fast_track2 =ftt2.get_as_df(has_header=True, index_colum=None, start=None, end=None, numerize=True, empty_value="")
                    ##Update fast track tracker
                    fast_track2.loc[:,'booking_month'] = pd.to_datetime(fast_track2['booking_month'])
                    fast_track2.loc[:,'Booking Month'] = fast_track2['booking_month'].dt.strftime('%B')
                    cols= ['partner_name', 'Fast_Track_Contract', 'booking_month',
                           'booking_amount', 'running_certs_total',
                           'bookings_over_50k', 'bookings_over50k_running_total',
                           'bookings_over_30k', 'bookings_over30k_running_total',
                           'eligible_for_rebate',
                           'contract_effective_date', 'expiration_date', 'date_fasttrack_expires', 'AUTO_EXT_DATE','months_remaining_incontract',
                           'months_remaining_FASTTRACK_eligibility', 'PF1', 'PF2', 'Old_rebate','PROGRAMMARKET',
                           'Booking Month']
                    fasttracks= fast_track2.loc[:, (cols)].copy()
                    month_= ['August']
                    currents= fasttracks.loc[fasttracks['Booking Month'].isin(month_)].copy()
                    close= ['CLOSE FOR PERFORMANCE TARGET 2 REBATE','CLOSE FOR PERFORMANCE TARGET 1 REBATE','CLOSE FOR EMERGING MARKET', 
                                   'CLOSE FOR DEVELOPED MARKET']
                                    #close_p= fast_track2.loc[fast_track2['eligible_for_rebate'].isin(close)]
                    achieved = ['$50,000 Rebate', '$30,000 Rebate', '$35,000 Rebate', '$55,000 Rebate']

                    currents.loc[fasttracks['eligible_for_rebate'].isin(achieved)]#.copy()
                                       
                    close_partners= currents.loc[fasttracks['eligible_for_rebate'].isin(close)].copy()
                    
                    partners_to_email= []
                    for i,row in currents.iterrows():
                        if row['Fast_Track_Contract']=='Old Fast Track Contract' and row['PROGRAMMARKET']=='DEVELOPED MARKET' and row['eligible_for_rebate'] in close:
                            #print(row)
                            exp_date= (row['date_fasttrack_expires'])
                            bks= 2 - (row['bookings_over_50k'])
                            certs= 4- (row['running_certs_total'])
                            exp= pd.to_datetime(exp_date, format='%Y/%m/%d')
                            ext_date= (exp + relativedelta(months=+1)).strftime(format='%Y-%m-%d')
                            partner= (row['partner_name'])
                            print("Email for: {}".format(partner))
                            partners_to_email.append(partner)


                            print('''To: partner email contact
                    Cc: Partner Manager (if they have one), partner-rebates-program@google.com
                    Send from: partner-rebates-program@google.com 

                    Subject:  You are close to earning the $50K GCP Fast Track rebate!


                    Dear Google Cloud Partner,

                    You have a high potential to earn the $50,000 Google Cloud Platform Fast Track Volume Sales Incentive (VSI) rebate.

                    In order to earn the payment, you need to do the following before your program expiry date of {}:
                    1. {} months of reselling $50,000 or more in GCP billings
                    2. {} additional GCP Certifications

                    Note that your program expiry date can be extended by 1 month to {} if during the last month of the Fast Track program period, you are able to resell $50,000 or more in GCP billings for the first time.

                    Please also register your bank account details with Google using the Partner Enrollment Form. You must enter US Dollars (USD) as your Currency, and partner-rebates-program@google.com as your Google email contact. If you earn this rebate, finishing this step now will ensure you don’t encounter any delays getting paid.

                    Thank you,

                    Google Cloud Partner Incentives Team'''.format(exp_date, bks, certs, ext_date))

                            old_dev_close_sub= "You are close to earning the $50K GCP Fast Track rebate!"
                            old_dev_close= """Dear Google Cloud Partner,

                    You have a high potential to earn the $50,000 Google Cloud Platform Fast Track Volume Sales Incentive (VSI) rebate.

                    In order to earn the payment, you need to do the following before your program expiry date of {}:
                    1. {} months of reselling $50,000 or more in GCP billings
                    2. {} additional GCP Certifications

                    Note that your program expiry date can be extended by 1 month to {} if during the last month of the Fast Track program period, you are able to resell $50,000 or more in GCP billings for the first time.

                    Please also register your bank account details with Google using the Partner Enrollment Form. You must enter US Dollars (USD) as your Currency, and partner-rebates-program@google.com as your Google email contact. If you earn this rebate, finishing this step now will ensure you don’t encounter any delays getting paid.

                    Thank you,

                    Google Cloud Partner Incentives Team""".format(exp_date, bks, certs, ext_date)
                            print("old_dev_close")
                            partner= re.sub("[ ,.]", "", partner)
                            exec(partner + " =old_dev_close")
                            partner_sub= partner + "sub"
                            exec(partner_sub + " =old_dev_close_sub")

                    ##___________________________________________________________________________________________________________________________________________________________
                    ##________________________________________________________________________________________________________________________________________________________________________
                    ##________________________________________________________________________________________________________________________________________________________________________
                        elif row['Fast_Track_Contract']=='Old Fast Track Contract' and row['PROGRAMMARKET']=='EMERGING MARKET' and row['eligible_for_rebate'] in close:
                            exp_date= (row['date_fasttrack_expires'])
                            bks= 2 - (row['bookings_over_30k'])
                            certs= 4- (row['running_certs_total'])
                            exp= pd.to_datetime(exp_date, format='%Y/%m/%d')
                            ext_date= (exp + relativedelta(months=+1)).strftime(format='%Y-%m-%d')
                            partner= (row['partner_name'])
                            print("Email for: {}".format(partner))
                            partners_to_email.append(partner)

                            print('''To: partner email contact
                    Cc: Partner Manager (if they have one), partner-rebates-program@google.com
                    Send from: partner-rebates-program@google.com 

                    Subject:  You are close to earning the $30K GCP Fast Track rebate!


                    Dear Google Cloud Partner,

                    You have a high potential to earn the $30,000 Google Cloud Platform Fast Track Volume Sales Incentive (VSI) rebate.

                    In order to earn the payment, you need to do the following before your program expiry date of {}:
                    1. {} month(s) of reselling $30,000 or more in GCP billings
                    2. {} additional GCP Certifications

                    Note that your program expiry date can be extended by 1 month to {} if during the last month of the Fast Track program period, you are able to resell $30,000 or more in GCP billings for the first time.

                    Please also register your bank account details with Google using the Partner Enrollment Form. You must enter US Dollars (USD) as your Currency, and partner-rebates-program@google.com as your Google email contact. If you earn this rebate, finishing this step now will ensure you don’t encounter any delays getting paid.

                    Thank you,

                    Google Cloud Partner Incentives Team'''.format(exp_date, bks, certs, ext_date))

                            old_em_close_sub= "You are close to earning the $30K GCP Fast Track rebate!"
                            old_em_close= """Dear Google Cloud Partner,

                    You have a high potential to earn the $30,000 Google Cloud Platform Fast Track Volume Sales Incentive (VSI) rebate.

                    In order to earn the payment, you need to do the following before your program expiry date of {}:
                    1. {} month(s) of reselling $30,000 or more in GCP billings
                    2. {} additional GCP Certifications

                    Note that your program expiry date can be extended by 1 month to {} if during the last month of the Fast Track program period, you are able to resell $30,000 or more in GCP billings for the first time.

                    Please also register your bank account details with Google using the Partner Enrollment Form. You must enter US Dollars (USD) as your Currency, and partner-rebates-program@google.com as your Google email contact. If you earn this rebate, finishing this step now will ensure you don’t encounter any delays getting paid.

                    Thank you,

                    Google Cloud Partner Incentives Team""".format(exp_date, bks, certs, ext_date)
                            print("old_em_close")
                            partner= re.sub("[ ,.]", "", partner)
                            exec(partner + " =old_em_close")
                            partner_sub= partner + "sub"
                            exec(partner_sub + " =old_em_close_sub")

                    ##___________________________________________________________________________________________________________________________________________________________
                    ##________________________________________________________________________________________________________________________________________________________________________
                    ##________________________________________________________________________________________________________________________________________________________________________    

                        elif row['eligible_for_rebate'] in achieved and row['Fast_Track_Contract']=='Old Fast Track Contract' and row['PROGRAMMARKET']=='EMERGING MARKET':
                            exp_date= (row['date_fasttrack_expires'])
                            bks= 2 - (row['bookings_over_50k'])
                            certs= 4- (row['running_certs_total'])
                            exp= pd.to_datetime(exp_date, format='%Y/%m/%d')
                            ext_date= (exp + relativedelta(months=+1)).strftime(format='%Y-%m-%d')
                            partner= (row['partner_name'])
                            print("Email for: {}".format(partner))
                            partners_to_email.append(partner)

                            print('''

                    To: Partners
                    CC: Partner Manager (if there is one), partner-rebates-program@google.com 

                    Subject: Congratulations, you earned the $30,000 GCP Fast Track Rebate!

                    Dear Google Cloud Partner,

                    Congratulations, you earned the $30,000 Google Cloud Platform Fast Track Volume Sales Incentive (VSI) rebate payment! We sincerely thank you for being a valued partner to Google Cloud. 

                    If you haven’t already, please use the Partner Enrollment Form to fill out your bank details as soon as possible so there are no delays issuing your rebate to you. When you fill this form out, enter US Dollars (USD) as your Currency, and partner-rebates-program@google.com as your Google contact. 

                    Thank you,

                    Google Cloud Partner Incentives Team'''.format(exp_date, bks, certs, ext_date))

                            old_em_achieved_sub= "Congratulations, you earned the $30,000 GCP Fast Track Rebate!"
                            old_em_achieved= """Dear Google Cloud Partner,

                    Congratulations, you earned the $30,000 Google Cloud Platform Fast Track Volume Sales Incentive (VSI) rebate payment! We sincerely thank you for being a valued partner to Google Cloud. 

                    If you haven’t already, please use the Partner Enrollment Form to fill out your bank details as soon as possible so there are no delays issuing your rebate to you. When you fill this form out, enter US Dollars (USD) as your Currency, and partner-rebates-program@google.com as your Google contact. 

                    Thank you,

                    Google Cloud Partner Incentives Team""".format(exp_date, bks, certs, ext_date)
                            print("old_em_achieved")
                            partner= re.sub("[ ,.]", "", partner)
                            exec(partner + " =old_em_achieved")
                            partner_sub= partner + "sub"
                            exec(partner_sub + " =old_em_achieved_sub")

                    ##___________________________________________________________________________________________________________________________________________________________
                    ##________________________________________________________________________________________________________________________________________________________________________
                    ##________________________________________________________________________________________________________________________________________________________________________        


                        elif row['eligible_for_rebate'] in achieved and row['Fast_Track_Contract']=='Old Fast Track Contract' and row['PROGRAMMARKET']=='DEVELOPED MARKET':
                            partner= (row['partner_name'])
                            print('Email for {}'.format(partner))
                            partners_to_email.append(partner)

                            print("""To: Partners
                    CC: Partner Manager (if there is one), partner-rebates-program@google.com 

                    Subject: Congratulations, you earned the $50,000 GCP Fast Track Rebate!

                    Dear Google Cloud Partner,

                    Congratulations, you earned the $50,000 Google Cloud Platform Fast Track Volume Sales Incentive (VSI) rebate payment! We sincerely thank you for being a valued partner to Google Cloud. 

                    If you haven’t already, please use the Partner Enrollment Form to fill out your bank details as soon as possible so there are no delays issuing your rebate to you. When you fill this form out, enter US Dollars (USD) as your Currency, and partner-rebates-program@google.com as your Google contact. 

                    Thank you,

                    Google Cloud Partner Incentives Team""".format(exp_date, bks, certs, ext_date))

                            old_DM_achieved_sub = 'Congratulations, you earned the $50,000 GCP Fast Track Rebate!'
                            old_DM_achieved= """Dear Google Cloud Partner,

                    Congratulations, you earned the $50,000 Google Cloud Platform Fast Track Volume Sales Incentive (VSI) rebate payment! We sincerely thank you for being a valued partner to Google Cloud. 

                    If you haven’t already, please use the Partner Enrollment Form to fill out your bank details as soon as possible so there are no delays issuing your rebate to you. When you fill this form out, enter US Dollars (USD) as your Currency, and partner-rebates-program@google.com as your Google contact. 

                    Thank you,

                    Google Cloud Partner Incentives Team""".format(exp_date, bks, certs, ext_date)
                            print("old_DM_achieved")
                            partner= re.sub("[ ,.]", "", partner)
                            exec(partner + " =old_DM_achieved")
                            partner_sub= partner + "sub"
                            exec(partner_sub + " =old_DM_achieved_sub")


                    ##___________________________________________________________________________________________________________________________________________________________
                    ##________________________________________________________________________________________________________________________________________________________________________
                    ##________________________________________________________________________________________________________________________________________________________________________    


                        elif row['eligible_for_rebate']== '$55,000 Rebate' and row['Fast_Track_Contract']=='New Fast Track Contract':
                            partner= (row['partner_name'])
                            print("Email for {}".format(partner))
                            partners_to_email.append(partner)

                            print( """To: Partners
                    CC: Partner Manager (if there is one), partner-rebates-program@google.com 

                    Subject: Congratulations, you earned the $55,000 GCP Fast Track Rebate!

                    Dear Google Cloud Partner,

                    Congratulations, you earned the $55,000 Google Cloud Platform Fast Track Volume Sales Incentive (VSI) rebate payment! We sincerely thank you for being a valued partner to Google Cloud. 

                    If you haven’t already, please use the Partner Enrollment Form to fill out your bank details as soon as possible so there are no delays issuing your rebate to you. When you fill this form out, enter US Dollars (USD) as your Currency, and partner-rebates-program@google.com as your Google contact. 

                    Thank you,

                    Google Cloud Partner Incentives Team""".format(exp_date, bks, certs, ext_date))
                            print("Email for: {}".format(partner))

                            new_pf2_achieved_sub= "Congratulations, you earned the $55,000 GCP Fast Track Rebate!"
                            new_pf2_achieved= """Dear Google Cloud Partner,

                    Congratulations, you earned the $55,000 Google Cloud Platform Fast Track Volume Sales Incentive (VSI) rebate payment! We sincerely thank you for being a valued partner to Google Cloud. 

                    If you haven’t already, please use the Partner Enrollment Form to fill out your bank details as soon as possible so there are no delays issuing your rebate to you. When you fill this form out, enter US Dollars (USD) as your Currency, and partner-rebates-program@google.com as your Google contact. 

                    Thank you,

                    Google Cloud Partner Incentives Team""".format(exp_date, bks, certs, ext_date)
                            print("new_pf2_achieved")
                            partner= re.sub("[ ,.]", "", partner)
                            exec(partner + " =new_pf2_achieved")
                            partner_sub= partner + "sub"
                            exec(partner_sub + " =new_pf2_achieved_sub")

                    ##___________________________________________________________________________________________________________________________________________________________
                    ##________________________________________________________________________________________________________________________________________________________________________
                    ##________________________________________________________________________________________________________________________________________________________________________    

                        elif row['eligible_for_rebate']== '$35,000 Rebate' and row['Fast_Track_Contract']=='New Fast Track Contract':
                            partner= (row['partner_name'])
                            print("Email for {}".format(partner))
                            partners_to_email.append(partner)

                            print("""To: Partners
                    CC: Partner Manager (if there is one), partner-rebates-program@google.com 

                    Subject: Congratulations, you earned the $35,000 GCP Fast Track Rebate!

                    Dear Google Cloud Partner,

                    Congratulations, you earned the $35,000 Google Cloud Platform Fast Track Volume Sales Incentive (VSI) rebate payment! We sincerely thank you for being a valued partner to Google Cloud. 

                    If you haven’t already, please use the Partner Enrollment Form to fill out your bank details as soon as possible so there are no delays issuing your rebate to you. When you fill this form out, enter US Dollars (USD) as your Currency, and partner-rebates-program@google.com as your Google contact. 

                    Thank you,

                    Google Cloud Partner Incentives Team""".format(exp_date, bks, certs, ext_date))


                            new_pf1_achieved_sub= "Congratulations, you earned the $35,000 GCP Fast Track Rebate!"
                            new_pf1_achieved= """Dear Google Cloud Partner,

                    Congratulations, you earned the $35,000 Google Cloud Platform Fast Track Volume Sales Incentive (VSI) rebate payment! We sincerely thank you for being a valued partner to Google Cloud. 

                    If you haven’t already, please use the Partner Enrollment Form to fill out your bank details as soon as possible so there are no delays issuing your rebate to you. When you fill this form out, enter US Dollars (USD) as your Currency, and partner-rebates-program@google.com as your Google contact. 

                    Thank you,

                    Google Cloud Partner Incentives Team""".format(exp_date, bks, certs, ext_date)
                            print("new_pf1_achieved")
                            partner= re.sub("[ ,.]", "", partner)
                            exec(partner + " =new_pf1_achieved")
                            partner_sub= partner + "sub"
                            exec(partner_sub + " =new_pf1_achieved_sub")

                    ##___________________________________________________________________________________________________________________________________________________________
                    ##________________________________________________________________________________________________________________________________________________________________________
                    ##________________________________________________________________________________________________________________________________________________________________________    

                        elif row['Fast_Track_Contract']=='New Fast Track Contract' and row['eligible_for_rebate'] in close:
                            exp_date= (row['date_fasttrack_expires'])
                            bks= 2 - (row['bookings_over_30k'])
                            certs= 4- (row['running_certs_total'])
                            bks2= 2 - (row['bookings_over_50k'])
                            certs2= 6- (row['running_certs_total'])
                            partner= (row['partner_name'])
                            exp= pd.to_datetime(exp_date, format='%Y/%m/%d')
                            ext_date= (exp + relativedelta(months=+1)).strftime(format='%Y-%m-%d')
                            print("Email for: {}".format(partner))
                            partners_to_email.append(partner)

                            print('''To: partner email contact
                    Cc: Partner Manager (if they have one), cloud-partners-incentives@google.com
                    Send from: cloud-partners-incentives@google.com 

                    Subject:  You are close to earning up to USD 55,000 in the GCP Fast Track rebate!

                    Dear Google Cloud Partner,

                    You have a high potential to earn the USD $35,000 or $55,000 Google Cloud Platform (GCP) Fast Track Volume Sales Incentive (VSI) rebate.

                    In order to earn any rebate through this program you must complete the following before your program expiry date of {}:

                    To earn up to $35,000 in rebate:
                    1.Earn {} or more new GCP Certifications
                    2.{} months of reselling $30,000 or more in GCP billings

                    To earn up to $55,000 in rebate:
                    1.Earn {} or more new GCP Certifications
                    2.{} month(s) of reselling $50,000 or more in GCP billings


                    We also recommend you register your bank account details with Google using the Partner Enrollment Form if you haven’t done so already. You must enter US Dollars (USD) as your Currency, and cloud-partners-incentives@google.com as your Google email contact. If you earn this rebate, finishing this step now will ensure you don’t encounter any delays getting paid.

                    Thank you,

                    Google Cloud Partner Incentives Team'''.format(exp_date, certs,bks,certs2,bks2))

                            new_close_sub= "You are close to earning up to USD 55,000 in the GCP Fast Track rebate!"
                            new_close= """Dear Google Cloud Partner,

                    You have a high potential to earn the USD $35,000 or $55,000 Google Cloud Platform (GCP) Fast Track Volume Sales Incentive (VSI) rebate.

                    In order to earn any rebate through this program you must complete the following before your program expiry date of {}:

                    To earn up to $35,000 in rebate:
                    1.Earn {} or more new GCP Certifications
                    2.{} months of reselling $30,000 or more in GCP billings

                    To earn up to $55,000 in rebate:
                    1.Earn {} or more new GCP Certifications
                    2.{} month(s) of reselling $50,000 or more in GCP billings


                    We also recommend you register your bank account details with Google using the Partner Enrollment Form if you haven’t done so already. You must enter US Dollars (USD) as your Currency, and cloud-partners-incentives@google.com as your Google email contact. If you earn this rebate, finishing this step now will ensure you don’t encounter any delays getting paid.

                    Thank you,

                    Google Cloud Partner Incentives Team""".format(exp_date, certs,bks,certs2,bks2).format(exp_date, certs,bks,certs2,bks2)
                            print("new_close")
                            partner= re.sub("[ ,.]", "", partner)
                            exec(partner + " =new_close")
                            partner_sub= partner + "sub"
                            exec(partner_sub + " =new_close_sub")

                    speak("Would you like to email these partners?") 
                    again = str(input("Enter yes/no"))
                    if again == "yes":
#                         def send_email(orders):
#                             SCOPES = 'https://mail.google.com/'
#                             store = file.Storage('token.json')
#                             creds = store.get()
#                             if not creds or creds.invalid:
#                                 flow = client.flow_from_clientsecrets('credentials.json', SCOPES)
#                                 creds = tools.run_flow(flow, store)
#                             service = discovery.build('gmail','v1',http=creds.authorize(Http()))
#                             message_text = orders
#                             created_message = create_message('cloud-partners-incentives@google.com','malikhasan@google.com',eval(partner_sub), message_text)
#                             send_message(service, 'from', created_message)
                    
                        speak("Please pick a partner to email")
                        print(partners_to_email)
                        again3= again = str(input("Pick"))
                        if again3 in partners_to_email:
                            partner= re.sub("[ ,.]", "", again3)
                            partner_sub= partner+"sub"
                            
                        send_email(eval(partner))
                        speak("Email has been sent to {}".format(again3))
                    
                    else:
                        speak("OK, Moving On")
                    
        
                    
                    
                    
                    
            
            if "deal reg" in prog and "update" in response:
                print('{}: {}'.format(your_name, response))
                current_date= (datetime.now().strftime("%d %B %Y"))
                speak("Please confirm you want to update the Deal Reg Tracker")
                confirm = (str(input("Enter yes/no "))) #int(float('196.01'))
                copy = (str(input("Do you want to create a copy of the current version? Enter yes/no")))
                
                if confirm == "yes" and copy =="no":
                    gs = pygsheets.authorize(service_account_file='My Project 1-c799865aecf9.json')
                    scope = ['https://spreadsheets.google.com/feeds','https://www.googleapis.com/auth/drive']
                    # UPDATING SHEET7
                    dr = gs.open('Example')
                    drr= dr[5] ###Named Sheet7
                    bookings=drr.get_as_df(has_header=True, index_colum=None, start=None, end=None, numerize=True, empty_value="")
                    bookings.rename(columns={'partner':'Partner_Name SFDC', 'Partner_Involved_Object__c':'Partner_SFDC_ID', 
                                             'customer_accountID':'Customer Account ID',
                                               'customer':'Customer Account Name', 'partner_new_amount':'Booking G Suite',
                                             'Created_date':'Opportunity Creation Date',
                                               'support_start_date':'Support Start Date', 'support_end_date':'Support End Date', 
                                                 'opp_type':'Type of Opportunity? (New/Upsell/etc)', 
                                                 'enduser_domain':'Opportunity domain',
                                               'region':'Region', 'Opportunity_ID_18__c':'Opportunity ID', 
                                               'unify_product_category_2':'Product (from Salesforce)', 
                                                 'booking_date':'Booking Date', 
                                             'booking_month':'Booking Month'}, inplace=True)
                    bookings['Opportunity domain']= bookings['Opportunity domain'].fillna('N/A')
                    #bookings.drop(columns='V10_oppty', inplace= True)
                    bookings.loc[:,'Booking Date'] = pd.to_datetime(bookings['Booking Date'])
                    bookings.loc[:,'Booking Month'] = bookings['Booking Date'].dt.strftime('%B')
                    sku_bookings=bookings.groupby(['Name','Partner_Name SFDC', 'Partner_SFDC_ID','Customer Account ID','Customer Account Name','enduser_customer_id','Booking Date','Primary_Product_interest__c','Opportunity Creation Date','Support Start Date', 'Support End Date','Type of Opportunity? (New/Upsell/etc)','Region','Booking Month','Opportunity domain','Opportunity ID','Product (from Salesforce)', 'sku_description'], as_index=True).agg({'sku_count':'sum', 'Booking G Suite':'sum'})                        
                    runningtotal= sku_bookings.groupby(['Name','enduser_customer_id'])['Booking G Suite'].cumsum()
                    sku_bookings.loc[:, 'Running_Total']= runningtotal
                    sku_bookings.loc[:,'Rebate Payout at G Suite (paid monthly)']= sku_bookings.loc[:, 'Booking G Suite'].apply(lambda x: x*.06 if x>=18000 else 0)
                    sku_bookings# The dataframe to add into the blank sheet 
                    drr.set_dataframe(sku_bookings.reset_index(), start='A1' ,copy_index=True, copy_head= True, fit=True)
                    # UPDATING SHEET9
                    bookings=drr.get_as_df(has_header=True, index_colum=None, start=None, end=None, numerize=True, empty_value="")
                    bookings.rename(columns={'partner':'Partner_Name SFDC', 'Partner_Involved_Object__c':'Partner_SFDC_ID', 
                                             'customer_accountID':'Customer Account ID',
                                               'customer':'Customer Account Name', 'partner_new_amount':'Booking G Suite',
                                             'Created_date':'Opportunity Creation Date',
                                               'support_start_date':'Support Start Date', 'support_end_date':'Support End Date', 
                                                 'opp_type':'Type of Opportunity? (New/Upsell/etc)', 
                                                 'enduser_domain':'Opportunity domain',
                                               'region':'Region', 'Opportunity_ID_18__c':'Opportunity ID', 
                                               'unify_product_category_2':'Product (from Salesforce)', 
                                                 'booking_date':'Booking Date', 
                                             'booking_month':'Booking Month'}, inplace=True)
                    bookings['Opportunity domain']= bookings['Opportunity domain'].fillna('N/A')
                    #bookings.drop(columns='V10_oppty', inplace= True)
                    bookings.drop(columns='Product (from Salesforce)', inplace= True)
                    bookings.drop(columns='Region', inplace= True)
                    bookings.drop(columns='sku_description', inplace= True)
                    bookings.drop(columns='sku_count', inplace= True)
                    bookings.loc[:,'Booking Date'] = pd.to_datetime(bookings['Booking Date'])
                    bookings.loc[:,'Booking Month'] = bookings['Booking Date'].dt.strftime('%B')
                    sku_bookings=bookings.groupby(['Name','Partner_Name SFDC', 'Partner_SFDC_ID','Customer Account ID','Customer Account Name','enduser_customer_id','Booking Date','Primary_Product_interest__c','Opportunity Creation Date','Support Start Date', 'Support End Date','Type of Opportunity? (New/Upsell/etc)','Booking Month','Opportunity domain','Opportunity ID'], as_index=True, sort=False).agg({'Booking G Suite':'sum'})                        
                    runningtotal= sku_bookings.groupby(['Name','enduser_customer_id'])['Booking G Suite'].cumsum()
                    sku_bookings.loc[:, 'Running_Total']= runningtotal
                    sku_bookings.loc[:,'Rebate Payout at G Suite (paid monthly)']= sku_bookings.loc[:, 'Booking G Suite'].apply(lambda x: x*.06 if x>=18000 else 0)
                    sku_bookings# The dataframe to add into the blank sheet 
                    #select the new sheet which is Sheet9 in Example Gsheet
                    wks = dr[6]
                    wks.set_dataframe(sku_bookings.reset_index(), start='A1' ,copy_index=False, copy_head= True, fit=True)
                    ####Reorder column order to match deal reg sheet
                    bookings_reorder=wks.get_as_df(has_header=True, index_colum=None, start=None, end=None, numerize=True, empty_value="")
                    cols = ['Booking Month', 'Name', 'Opportunity domain','Partner_SFDC_ID','Partner_Name SFDC','Opportunity ID',
                    'Customer Account ID','Customer Account Name','Type of Opportunity? (New/Upsell/etc)', 
                    'Opportunity Creation Date','Booking G Suite','Booking Date','Support Start Date',
                    'Support End Date','Running_Total','Rebate Payout at G Suite (paid monthly)']
                    sku_bookings=bookings_reorder.reindex(columns = cols)
                    sku_bookings.loc[:, 'Rebate Payout at G Suite (paid monthly)']= sku_bookings.groupby('Name')['Booking G Suite'].transform(lambda x: x *.06 if x[:].sum() >= 18000 else 0)
                    wks.set_dataframe(sku_bookings, start='A1' ,copy_index=False, copy_head= True, fit=True)
                    #__________________________________________________________________________________________________________________________________________
                    # __________________________________________________________________________________________________________________________________________
                    #__________________________________________________________________________________________________________________________________
                    #DEAL TRIX AUTOMATION
                    #___________________________________________________________________________________________________________________

                    trial = dr[7]##Copy of Deal Reg Payout tab
                    dr_trix=trial.get_as_df(has_header=True, index_colum=None, start=None, end=None, numerize=True, empty_value="")
                    DR_copy= dr_trix.loc[:, 'Booking Month':'Running_Total']
                    book = dr[6]########skU-bookings
                    booking=book.get_as_df(has_header=True, index_colum=None, start=None, end=None, numerize=True, empty_value="")
                    booker=booking.loc[:, 'Booking Month':'Running_Total']
                    common = pd.merge(booker, DR_copy, how='inner')
                    df1 = pd.merge(booker, DR_copy, indicator=True, how='outer')
                    only_BK =df1[df1.loc[:, '_merge']=='left_only'].reset_index(drop=True)
                    only_DR =df1[df1.loc[:, '_merge']=='right_only'].reset_index(drop=True)
                    only_BK= only_BK.iloc[:, :-1]
                    only_DR= only_DR.iloc[:, :-1]                         
                    # Bookings THAT ARE NOT from deal reg tracker opptys: Can think of these as NEW opptys to be added
                    only_BK.loc[:, 'Booking G Suite']= pd.to_numeric(only_BK['Booking G Suite'], downcast='float')
                    guess = only_BK[~only_BK['Name'].isin(only_DR['Name'])]
                    guess1= guess.loc[(guess['Booking G Suite'] > 0)]
                    # BOOKINGS THAT ARE IN OPPTY's in DEAL reg Tracker: THink of these as deals to be added to opptys already in the tracker
                    new_existing= only_BK.loc[(only_BK['Booking G Suite'] >0 ) & only_BK['Name'].isin(only_DR['Name'])]
                    new_existing
                    result = pd.concat([guess1, new_existing, DR_copy], ignore_index=True)
                    cols =[]
                    for col in result.columns:
                        if col != 'Rebate Payout at G Suite (paid monthly)':
                            cols.append(col)
                    result = pd.merge(result, dr_trix, how='left', on=cols)
                    result= result.drop(columns=['Type of Opportunity? (New/Upsell/etc)', 'Opportunity Creation Date','Q2 Booking reported in May 18 (incorrect)','Over/(Under) paid','Q2 rebate reported in May 18 (incorrect)'])

                    result= result.sort_values(by=['Name', 'Booking Date'])

                    result['Running_Total'] = result.groupby('Name')['Booking G Suite'].transform(lambda g: g.cumsum())
                    result.loc[:,'Booking Date'] = pd.to_datetime(result['Booking Date'])
                    result['Rebate Exp Date']=result.groupby(['Name'])['Booking Date'].transform(lambda x: x.min()+ relativedelta(years=+1) )
                    
                    runrebate= result['Running_Total'].apply(lambda x: x *.06 if x >= 18000 else 0)
                    result.insert(loc=12, column='Running_Rebate', value=runrebate)

                    newrebates=result.groupby(['Name'])['Running_Rebate'].transform(lambda x: x- x.shift(1))
                    result.insert(loc=11, column='New_Rebate', value=newrebates)
                    result['New_Rebate']= result['New_Rebate'].fillna(result['Running_Rebate'])

                    #rebate_counts =result[result["Total Rebate Earned"]>0].nunique()["Total Rebate Earned"]
                    rr= dr[10] ###Named Sheet13
                    rr.set_dataframe(result, start='A1' ,copy_index=False, copy_head= True, fit=True)
                    speak("The Deal Reg Tracker has been updated")
                    display(result.iloc[:, 0:15])
 
                elif confirm=="yes" and copy =="yes":
                    gs = pygsheets.authorize(service_account_file='My Project 1-c799865aecf9.json')
                    dr = gs.open('Example')
                    drr= dr[10]
                    ##make copy of deal reg, takes a copy of sheet7 and inserts it into new sheet
                    drf = dr.add_worksheet("Sheet7copy", src_worksheet=sh.worksheet_by_title("Sheet7"))
                    print("Deal Reg copy successfully created")
                    # UPDATING SHEET7
                    drr= dr[5] ###Named Sheet7
                    bookings=drr.get_as_df(has_header=True, index_colum=None, start=None, end=None, numerize=True, empty_value="")
                    bookings.rename(columns={'partner':'Partner_Name SFDC', 'Partner_Involved_Object__c':'Partner_SFDC_ID', 
                                             'customer_accountID':'Customer Account ID',
                                               'customer':'Customer Account Name', 'partner_new_amount':'Booking G Suite',
                                             'Created_date':'Opportunity Creation Date',
                                               'support_start_date':'Support Start Date', 'support_end_date':'Support End Date', 
                                                 'opp_type':'Type of Opportunity? (New/Upsell/etc)', 
                                                 'enduser_domain':'Opportunity domain',
                                               'region':'Region', 'Opportunity_ID_18__c':'Opportunity ID', 
                                               'unify_product_category_2':'Product (from Salesforce)', 
                                                 'booking_date':'Booking Date', 
                                             'booking_month':'Booking Month'}, inplace=True)
                    bookings['Opportunity domain']= bookings['Opportunity domain'].fillna('N/A')
                    #bookings.drop(columns='V10_oppty', inplace= True)
                    bookings.loc[:,'Booking Date'] = pd.to_datetime(bookings['Booking Date'])
                    bookings.loc[:,'Booking Month'] = bookings['Booking Date'].dt.strftime('%B')
                    sku_bookings=bookings.groupby(['Name','Partner_Name SFDC', 'Partner_SFDC_ID','Customer Account ID','Customer Account Name','enduser_customer_id','Booking Date','Primary_Product_interest__c','Opportunity Creation Date','Support Start Date', 'Support End Date','Type of Opportunity? (New/Upsell/etc)','Region','Booking Month','Opportunity domain','Opportunity ID','Product (from Salesforce)', 'sku_description'], as_index=True).agg({'sku_count':'sum', 'Booking G Suite':'sum'})                        
                    runningtotal= sku_bookings.groupby(['Name','enduser_customer_id'])['Booking G Suite'].cumsum()
                    sku_bookings.loc[:, 'Running_Total']= runningtotal
                    sku_bookings.loc[:,'Rebate Payout at G Suite (paid monthly)']= sku_bookings.loc[:, 'Booking G Suite'].apply(lambda x: x*.06 if x>=18000 else 0)
                    sku_bookings# The dataframe to add into the blank sheet 
                    drr.set_dataframe(sku_bookings.reset_index(), start='A1' ,copy_index=True, copy_head= True, fit=True)
                    # UPDATING SHEET9
                    bookings=drr.get_as_df(has_header=True, index_colum=None, start=None, end=None, numerize=True, empty_value="")
                    bookings.rename(columns={'partner':'Partner_Name SFDC', 'Partner_Involved_Object__c':'Partner_SFDC_ID', 
                                             'customer_accountID':'Customer Account ID',
                                               'customer':'Customer Account Name', 'partner_new_amount':'Booking G Suite',
                                             'Created_date':'Opportunity Creation Date',
                                               'support_start_date':'Support Start Date', 'support_end_date':'Support End Date', 
                                                 'opp_type':'Type of Opportunity? (New/Upsell/etc)', 
                                                 'enduser_domain':'Opportunity domain',
                                               'region':'Region', 'Opportunity_ID_18__c':'Opportunity ID', 
                                               'unify_product_category_2':'Product (from Salesforce)', 
                                                 'booking_date':'Booking Date', 
                                             'booking_month':'Booking Month'}, inplace=True)
                    bookings['Opportunity domain']= bookings['Opportunity domain'].fillna('N/A')
                    #bookings.drop(columns='V10_oppty', inplace= True)
                    bookings.drop(columns='Product (from Salesforce)', inplace= True)
                    bookings.drop(columns='Region', inplace= True)
                    bookings.drop(columns='sku_description', inplace= True)
                    bookings.drop(columns='sku_count', inplace= True)
                    bookings.loc[:,'Booking Date'] = pd.to_datetime(bookings['Booking Date'])
                    bookings.loc[:,'Booking Month'] = bookings['Booking Date'].dt.strftime('%B')
                    sku_bookings=bookings.groupby(['Name','Partner_Name SFDC', 'Partner_SFDC_ID','Customer Account ID','Customer Account Name','enduser_customer_id','Booking Date','Primary_Product_interest__c','Opportunity Creation Date','Support Start Date', 'Support End Date','Type of Opportunity? (New/Upsell/etc)','Booking Month','Opportunity domain','Opportunity ID'], as_index=True, sort=False).agg({'Booking G Suite':'sum'})                        
                    runningtotal= sku_bookings.groupby(['Name','enduser_customer_id'])['Booking G Suite'].cumsum()
                    sku_bookings.loc[:, 'Running_Total']= runningtotal
                    sku_bookings.loc[:,'Rebate Payout at G Suite (paid monthly)']= sku_bookings.loc[:, 'Booking G Suite'].apply(lambda x: x*.06 if x>=18000 else 0)
                    sku_bookings# The dataframe to add into the blank sheet 
                    #select the new sheet which is Sheet9 in Example Gsheet
                    wks = dr[6]
                    wks.set_dataframe(sku_bookings.reset_index(), start='A1' ,copy_index=False, copy_head= True, fit=True)
                    ####Reorder column order to match deal reg sheet
                    bookings_reorder=wks.get_as_df(has_header=True, index_colum=None, start=None, end=None, numerize=True, empty_value="")
                    cols = ['Booking Month', 'Name', 'Opportunity domain','Partner_SFDC_ID','Partner_Name SFDC','Opportunity ID',
                    'Customer Account ID','Customer Account Name','Type of Opportunity? (New/Upsell/etc)', 
                    'Opportunity Creation Date','Booking G Suite','Booking Date','Support Start Date',
                    'Support End Date','Running_Total','Rebate Payout at G Suite (paid monthly)']
                    sku_bookings=bookings_reorder.reindex(columns = cols)
                    sku_bookings.loc[:,'Rebate Payout at G Suite (paid monthly)']= sku_bookings.loc[:, 'Booking G Suite'].apply(lambda x: x*.06 if x>=18000 else 0)
                    wks.set_dataframe(sku_bookings, start='A1' ,copy_index=False, copy_head= True, fit=True)
                    #__________________________________________________________________________________________________________________________________________
                    # __________________________________________________________________________________________________________________________________________
                    #__________________________________________________________________________________________________________________________________
                    #DEAL TRIX AUTOMATION
                    #___________________________________________________________________________________________________________________
                    trial = dr[7]##Copy of Deal Reg Payout tab
                    dr_trix=trial.get_as_df(has_header=True, index_colum=None, start=None, end=None, numerize=True, empty_value="")
                    DR_copy= dr_trix.loc[:, 'Booking Month':'Running_Total']
                    book = dr[6]########skU-bookings
                    booking=book.get_as_df(has_header=True, index_colum=None, start=None, end=None, numerize=True, empty_value="")
                    booker=booking.loc[:, 'Booking Month':'Running_Total']
                    common = pd.merge(booker, DR_copy, how='inner')
                    df1 = pd.merge(booker, DR_copy, indicator=True, how='outer')
                    only_BK =df1[df1.loc[:, '_merge']=='left_only'].reset_index(drop=True)
                    only_DR =df1[df1.loc[:, '_merge']=='right_only'].reset_index(drop=True)
                    only_BK= only_BK.iloc[:, :-1]
                    only_DR= only_DR.iloc[:, :-1]                         
                    # Bookings THAT ARE NOT from deal reg tracker opptys: Can think of these as NEW opptys to be added
                    only_BK.loc[:, 'Booking G Suite']= pd.to_numeric(only_BK['Booking G Suite'], downcast='float')
                    guess = only_BK[~only_BK['Name'].isin(only_DR['Name'])]
                    guess1= guess.loc[(guess['Booking G Suite'] > 0)]
                    # BOOKINGS THAT ARE IN OPPTY's in DEAL reg Tracker: THink of these as deals to be added to opptys already in the tracker
                    new_existing= only_BK.loc[(only_BK['Booking G Suite'] >0 ) & only_BK['Name'].isin(only_DR['Name'])]
                    result = pd.concat([guess1, new_existing, DR_copy], ignore_index=True)
                    cols =[]
                    for col in result.columns:
                        if col != 'Rebate Payout at G Suite (paid monthly)':
                            cols.append(col)
                    result = pd.merge(result, dr_trix, how='left', on=cols)
                    result= result.drop(columns=['Type of Opportunity? (New/Upsell/etc)', 'Opportunity Creation Date','Q2 Booking reported in May 18 (incorrect)','Over/(Under) paid','Q2 rebate reported in May 18 (incorrect)'])

                    result= result.sort_values(by=['Name', 'Booking Date'])

                    result['Running_Total'] = result.groupby('Name')['Booking G Suite'].transform(lambda g: g.cumsum())
                    result.loc[:,'Booking Date'] = pd.to_datetime(result['Booking Date'])
                    result['Rebate Exp Date']=result.groupby(['Name'])['Booking Date'].transform(lambda x: x.min()+ relativedelta(years=+1) )
                    runrebate= result['Running_Total'].apply(lambda x: x *.06 if x >= 18000 else 0)
                    result.insert(loc=12, column='Running_Rebate', value=runrebate)
                    newrebates=result.groupby(['Name'])['Running_Rebate'].transform(lambda x: x- x.shift(1))
                    result.insert(loc=11, column='New_Rebate', value=newrebates)
                    result['New_Rebate']= result['New_Rebate'].fillna(result['Running_Rebate'])

                    #rebate_counts =result[result["Total Rebate Earned"]>0].nunique()["Total Rebate Earned"]
                    rr= dr[10] ###Named Sheet13
                    rr.set_dataframe(result, start='A1' ,copy_index=False, copy_head= True, fit=True)
                    speak("The Deal Reg Tracker has been updated and a copy has been saved ")
                    display(result.iloc[:, 0:15])
                else:
                    speak("No confirmation was provided for this request".format(your_name))
#________________________________________________________________________________________________________________________________________________________                
#########################################################################################################################################################

# %% [markdown]
# # INITIALIZER

# %%
#________________________________________________________________________________________________________________________________________________________                
#########################################################################################################################################################
engine = pyttsx3.init()
engine.setProperty('voice', 'com.apple.speech.synthesis.voice.daniel')
r = sr.Recognizer()
with sr.Microphone() as source:
        r.adjust_for_ambient_noise(source)
        engine.say('Hello I am Stem, what is your, name?')
        engine.runAndWait()
        
        while True:
            try:
                name = r.listen(source)
                r.recognize_google(name)
                your_name= r.recognize_google(name, key='AIzaSyAdTyq2lSSoinplSa-O1g1syZhhaPgUu1Y')
                your_name.split(" ")[-1]
                your_name= your_name.split(" ")[-1]
                print(your_name)
            except sr.UnknownValueError:
                print("Google Speech Recognition could not understand audio")
                speak("Sorry I did not catch that, please tell me your name again")
            #except sr.RequestError as e:
                #print("Could not request results from Google Speech Recognition service; {0}".format(e))
                continue
            break

#r = sr.Recognizer()
engine.say('Nice to meet you {}, How Can I Help you?'.format(your_name))
engine.runAndWait()
print("Stem: How can I help you?")
    
global running
running = True
    
while running==True:
    try:
        recorder()
    except sr.UnknownValueError:
        speak("Please say that again")
        continue
    else:
        if running==True:
            print("Stem: Is there anything else I can help you with {}?".format(your_name))
            engine.say("Is there anything else I can help you with {}?".format(your_name))
            engine.runAndWait()
        elif running==False:
            print('Thank You {}!'.format(your_name))
# Out:
# Gibran
# Stem: How can I help you?
# Gibran : eBay the voice sounds like Batman so I can change it as well
# Please specify a valid request Gibran
# Stem: Is there anything else I can help you with Gibran?
# Gibran: please show me all rebates for deal Reg
# OK, pulling up the accumulative Deal Reg Report
# Stem: OK, pulling up the accumulative Deal Reg Report
# As of 12 September 2018 there have been 25 rebates totalling 39799.0 for 10 partners
#                                                                                                        Booking G Suite  \
# Partner_Name SFDC                                  Name
# Avalon Solutions AB                                Ryobi Geotechnique International Pte Ltd - Apps...     17511.090546
# Cloudbakers, LLC                                   Moors & Cabot - Apps 220 G Suite Upgrades 2018 ...     25624.590000
# Densan System Co.,Ltd.                             AM - morozoff.co.jp - 350*GSB_&_210*GSB_Deskles...       707.460013
# ...

# %%
recorder()
# Out:
# Gibran: please update the deal reg tracker
# Please confirm you want to update the Deal Reg Tracker
# Enter yes/no yes
# Do you want to create a copy of the current version? Enter yes/nono
# The Deal Reg Tracker has been updated
#    Booking Month                                               Name  \
# 64         April                                               #N/A
# 63          June                                               #N/A
# 0         August  AM - morozoff.co.jp - 350*GSB_&_210*GSB_Deskle...
# 1         August  AM - morozoff.co.jp - 350*GSB_&_210*GSB_Deskle...
# 2         August  AM - morozoff.co.jp - 350*GSB_&_210*GSB_Deskle...
# 3           June                                 B Bosch - Apps 600
# 4           July  CORPORACIÓN AUTÓNOMA REGIONAL DE BOYACÁ - Apps...
# 5           July  CORPORACIÓN AUTÓNOMA REGIONAL DE BOYACÁ - Apps...
# 6           June                  Fletes Mexico SA de CV - Apps 223
# ...

# %%
partners_to_email = ['D.A.Consortium Inc.', 'MediaAgility UK LTD', 'TS Consultancy CO., LTD.']
again = str(input("Enter yes/no"))
if again == "yes":
    print("Please pick a partner to email")
    print(partners_to_email)
    again3= again = str(input("Pick"))
    if again3 in partners_to_email:
        partner= re.sub("[ ,.]", "", again3)
        partner_sub= partner+"sub"

        def create_message(sender, to, subject, message_text):
            message = MIMEText(message_text)
            message['to'] = to
            message['from'] = sender
            message['subject'] = subject
            return {'raw': base64.urlsafe_b64encode(message.as_string().encode()).decode()}

        def send_message(service, user_id, message):

            message = (service.users().messages().send(userId="me", body=message).execute())
            print('Message Id: %s' % message['id'])
            return message

        def send_email(orders):
            SCOPES = 'https://mail.google.com/'
            store = file.Storage('token.json')
            creds = store.get()
            if not creds or creds.invalid:
                flow = client.flow_from_clientsecrets('credentials.json', SCOPES)
                creds = tools.run_flow(flow, store)
            service = discovery.build('gmail','v1',http=creds.authorize(Http()))
            message_text = orders
            created_message = create_message('cloud-partners-incentives@google.com','malikhasan@google.com',eval(partner_sub), message_text)
            send_message(service, 'from', created_message)

        send_email(eval(partner))
        print("Email has been sent to {}".format(again3))
# Out:
# Enter yes/noyes
# Please pick a partner to email
# ['D.A.Consortium Inc.', 'MediaAgility UK LTD', 'TS Consultancy CO., LTD.']
# PickMediaAgility UK LTD
# Message Id: 165cd51c581cce57
# Email has been sent to MediaAgility UK LTD

# %%
MediaAgilityUKLTDsub= "You are close to earning up to USD 55,000 in the GCP Fast Track rebate!"

# %%
TSConsultancyCOLTDsub= "Congratulations, you earned the $30,000 GCP Fast Track Rebate!"

# %%
DAConsortiumIncsub="You are close to earning the $50K GCP Fast Track rebate!"

# %%
MediaAgilityUKLTD
# Out:
# 'hello there'

# %%
gs = pygsheets.authorize(service_account_file='My Project 1-c799865aecf9.json')
scope = ['https://spreadsheets.google.com/feeds','https://www.googleapis.com/auth/drive']
fa = gs.open('GCP Fast Track - Tracker') 
ftt2 = fa[3]
ftt2.get_as_df(has_header=True, index_colum=None, start=None, end=None, numerize=True, empty_value="")
fast_track2 =ftt2.get_as_df(has_header=True, index_colum=None, start=None, end=None, numerize=True, empty_value="")
fast_track2.loc[:, 'PF1']= fast_track2.apply(p1, axis=1)
fast_track2.loc[:, 'PF2']=fast_track2.apply(p2, axis=1)
fast_track2.loc[:, 'Old_rebate']= fast_track2.apply(f, axis=1)
##Update fast track tracker

fast_track2.loc[:,'booking_month'] = pd.to_datetime(fast_track2['booking_month'])
fast_track2.loc[:,'Booking Month'] = fast_track2['booking_month'].dt.strftime('%B')

cols= ['partner_name', 'Fast_Track_Contract', 'booking_month',
       'booking_amount', 'running_certs_total',
       'bookings_over_50k', 'bookings_over50k_running_total',
       'bookings_over_30k', 'bookings_over30k_running_total',
       'eligible_for_rebate',
       'contract_effective_date', 'expiration_date', 'date_fasttrack_expires', 'AUTO_EXT_DATE','months_remaining_incontract',
       'months_remaining_FASTTRACK_eligibility', 'PF1', 'PF2', 'Old_rebate','PROGRAMMARKET',
       'Booking Month']

fasttracks= fast_track2.loc[:, (cols)].copy()

currents= fasttracks.loc[fasttracks['Booking Month'].isin(month_found)].copy()

close= ['CLOSE FOR PERFORMANCE TARGET 2 REBATE','CLOSE FOR PERFORMANCE TARGET 1 REBATE','CLOSE FOR EMERGING MARKET', 
               'CLOSE FOR DEVELOPED MARKET']
                #close_p= fast_track2.loc[fast_track2['eligible_for_rebate'].isin(close)]
achieved = ['$50,000 Rebate', '$30,000 Rebate', '$35,000 Rebate', '$55,000 Rebate']

currents.loc[fasttracks['eligible_for_rebate'].isin(achieved)]#.copy()

close_partners= currents.loc[fasttracks['eligible_for_rebate'].isin(close)].copy()


for i,row in currents.iterrows():
    if row['Fast_Track_Contract']=='Old Fast Track Contract' and row['PROGRAMMARKET']=='DEVELOPED MARKET' and row['eligible_for_rebate'] in close:
        #print(row)
        exp_date= (row['date_fasttrack_expires'])
        bks= 2 - (row['bookings_over_50k'])
        certs= 4- (row['running_certs_total'])
        exp= pd.to_datetime(exp_date, format='%Y/%m/%d')
        ext_date= (exp + relativedelta(months=+1)).strftime(format='%Y-%m-%d')
        partner= (row['partner_name'])
        print("Email for: {}".format(partner))
        
        
        print('''To: partner email contact
Cc: Partner Manager (if they have one), partner-rebates-program@google.com
Send from: partner-rebates-program@google.com 

Subject:  You are close to earning the $50K GCP Fast Track rebate!


Dear Google Cloud Partner,

You have a high potential to earn the $50,000 Google Cloud Platform Fast Track Volume Sales Incentive (VSI) rebate.

In order to earn the payment, you need to do the following before your program expiry date of {}:
1. {} months of reselling $50,000 or more in GCP billings
2. {} additional GCP Certifications

Note that your program expiry date can be extended by 1 month to {} if during the last month of the Fast Track program period, you are able to resell $50,000 or more in GCP billings for the first time.

Please also register your bank account details with Google using the Partner Enrollment Form. You must enter US Dollars (USD) as your Currency, and partner-rebates-program@google.com as your Google email contact. If you earn this rebate, finishing this step now will ensure you don’t encounter any delays getting paid.

Thank you,

Google Cloud Partner Incentives Team'''.format(exp_date, bks, certs, ext_date))
              
        
    elif row['Fast_Track_Contract']=='Old Fast Track Contract' and row['PROGRAMMARKET']=='EMERGING MARKET' and row['eligible_for_rebate'] in close:
        exp_date= (row['date_fasttrack_expires'])
        bks= 2 - (row['bookings_over_30k'])
        certs= 4- (row['running_certs_total'])
        exp= pd.to_datetime(exp_date, format='%Y/%m/%d')
        ext_date= (exp + relativedelta(months=+1)).strftime(format='%Y-%m-%d')
        partner= (row['partner_name'])
        print("Email for: {}".format(partner))
        
        print('''To: partner email contact
Cc: Partner Manager (if they have one), partner-rebates-program@google.com
Send from: partner-rebates-program@google.com 

Subject:  You are close to earning the $30K GCP Fast Track rebate!


Dear Google Cloud Partner,

You have a high potential to earn the $30,000 Google Cloud Platform Fast Track Volume Sales Incentive (VSI) rebate.

In order to earn the payment, you need to do the following before your program expiry date of {}:
1. {} month(s) of reselling $30,000 or more in GCP billings
2. {} additional GCP Certifications

Note that your program expiry date can be extended by 1 month to {} if during the last month of the Fast Track program period, you are able to resell $30,000 or more in GCP billings for the first time.

Please also register your bank account details with Google using the Partner Enrollment Form. You must enter US Dollars (USD) as your Currency, and partner-rebates-program@google.com as your Google email contact. If you earn this rebate, finishing this step now will ensure you don’t encounter any delays getting paid.

Thank you,

Google Cloud Partner Incentives Team'''.format(exp_date, bks, certs, ext_date))
        
            
    elif row['eligible_for_rebate'] in achieved and row['Fast_Track_Contract']=='Old Fast Track Contract' and row['PROGRAMMARKET']=='EMERGING MARKET':
        exp_date= (row['date_fasttrack_expires'])
        bks= 2 - (row['bookings_over_50k'])
        certs= 4- (row['running_certs_total'])
        exp= pd.to_datetime(exp_date, format='%Y/%m/%d')
        ext_date= (exp + relativedelta(months=+1)).strftime(format='%Y-%m-%d')
        partner= (row['partner_name'])
        print("Email for: {}".format(partner))
        
        print('''
        
To: Partners
CC: Partner Manager (if there is one), partner-rebates-program@google.com 

Subject: Congratulations, you earned the $30,000 GCP Fast Track Rebate!

Dear Google Cloud Partner,

Congratulations, you earned the $30,000 Google Cloud Platform Fast Track Volume Sales Incentive (VSI) rebate payment! We sincerely thank you for being a valued partner to Google Cloud. 

If you haven’t already, please use the Partner Enrollment Form to fill out your bank details as soon as possible so there are no delays issuing your rebate to you. When you fill this form out, enter US Dollars (USD) as your Currency, and partner-rebates-program@google.com as your Google contact. 

Thank you,

Google Cloud Partner Incentives Team'''.format(exp_date, bks, certs, ext_date))
        
        
    elif row['eligible_for_rebate'] in achieved and row['Fast_Track_Contract']=='Old Fast Track Contract' and row['PROGRAMMARKET']=='DEVELOPED MARKET':
        print(partner= (row['partner_name']))
        
        print("""To: Partners
CC: Partner Manager (if there is one), partner-rebates-program@google.com 

Subject: Congratulations, you earned the $50,000 GCP Fast Track Rebate!

Dear Google Cloud Partner,

Congratulations, you earned the $50,000 Google Cloud Platform Fast Track Volume Sales Incentive (VSI) rebate payment! We sincerely thank you for being a valued partner to Google Cloud. 

If you haven’t already, please use the Partner Enrollment Form to fill out your bank details as soon as possible so there are no delays issuing your rebate to you. When you fill this form out, enter US Dollars (USD) as your Currency, and partner-rebates-program@google.com as your Google contact. 

Thank you,

Google Cloud Partner Incentives Team""".format(exp_date, bks, certs, ext_date))
        
        
    
    elif row['eligible_for_rebate']== '$55,000 Rebate' and row['Fast_Track_Contract']=='New Fast Track Contract':
        print(partner= (row['partner_name']))
        print( """To: Partners
CC: Partner Manager (if there is one), partner-rebates-program@google.com 

Subject: Congratulations, you earned the $55,000 GCP Fast Track Rebate!

Dear Google Cloud Partner,

Congratulations, you earned the $55,000 Google Cloud Platform Fast Track Volume Sales Incentive (VSI) rebate payment! We sincerely thank you for being a valued partner to Google Cloud. 

If you haven’t already, please use the Partner Enrollment Form to fill out your bank details as soon as possible so there are no delays issuing your rebate to you. When you fill this form out, enter US Dollars (USD) as your Currency, and partner-rebates-program@google.com as your Google contact. 

Thank you,

Google Cloud Partner Incentives Team""".format(exp_date, bks, certs, ext_date))
        print("Email for: {}".format(partner))
        
        
    elif row['eligible_for_rebate']== '$35,000 Rebate' and row['Fast_Track_Contract']=='New Fast Track Contract':
        print(partner= (row['partner_name']))
        print("""To: Partners
CC: Partner Manager (if there is one), partner-rebates-program@google.com 

Subject: Congratulations, you earned the $35,000 GCP Fast Track Rebate!

Dear Google Cloud Partner,

Congratulations, you earned the $35,000 Google Cloud Platform Fast Track Volume Sales Incentive (VSI) rebate payment! We sincerely thank you for being a valued partner to Google Cloud. 

If you haven’t already, please use the Partner Enrollment Form to fill out your bank details as soon as possible so there are no delays issuing your rebate to you. When you fill this form out, enter US Dollars (USD) as your Currency, and partner-rebates-program@google.com as your Google contact. 

Thank you,

Google Cloud Partner Incentives Team""".format(exp_date, bks, certs, ext_date))
        
    
    
    elif row['Fast_Track_Contract']=='New Fast Track Contract' and row['eligible_for_rebate'] in close:
        exp_date= (row['date_fasttrack_expires'])
        bks= 2 - (row['bookings_over_30k'])
        certs= 4- (row['running_certs_total'])
        bks2= 2 - (row['bookings_over_50k'])
        certs2= 6- (row['running_certs_total'])
        partner= (row['partner_name'])
        exp= pd.to_datetime(exp_date, format='%Y/%m/%d')
        ext_date= (exp + relativedelta(months=+1)).strftime(format='%Y-%m-%d')
        print("Email for: {}".format(partner))
        print('''To: partner email contact
Cc: Partner Manager (if they have one), cloud-partners-incentives@google.com
Send from: cloud-partners-incentives@google.com 

Subject:  You are close to earning up to USD 55,000 in the GCP Fast Track rebate!

Dear Google Cloud Partner,

You have a high potential to earn the USD $35,000 or $55,000 Google Cloud Platform (GCP) Fast Track Volume Sales Incentive (VSI) rebate.

In order to earn any rebate through this program you must complete the following before your program expiry date of {}:

To earn up to $35,000 in rebate:
1.Earn {} or more new GCP Certifications
2.{} months of reselling $30,000 or more in GCP billings

To earn up to $55,000 in rebate:
1.Earn {} or more new GCP Certifications
2.{} month(s) of reselling $50,000 or more in GCP billings


We also recommend you register your bank account details with Google using the Partner Enrollment Form if you haven’t done so already. You must enter US Dollars (USD) as your Currency, and cloud-partners-incentives@google.com as your Google email contact. If you earn this rebate, finishing this step now will ensure you don’t encounter any delays getting paid.

Thank you,

Google Cloud Partner Incentives Team'''.format(exp_date, certs,bks,certs2,bks2))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-9931091f0a3f> in <module>()
#      24 fasttracks= fast_track2.loc[:, (cols)].copy()
#      25
# ---> 26 currents= fasttracks.loc[fasttracks['Booking Month'].isin(month_found)].copy()
#      27
#      28 close= ['CLOSE FOR PERFORMANCE TARGET 2 REBATE','CLOSE FOR PERFORMANCE TARGET 1 REBATE','CLOSE FOR EMERGING MARKET',
#
# NameError: name 'month_found' is not defined

# %%
from apiclient import discovery
from httplib2 import Http
from oauth2client import file, client, tools
import base64
from email.mime.audio import MIMEAudio
from email.mime.base import MIMEBase
from email.mime.image import MIMEImage
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
import mimetypes
import os

def create_message(sender, to, subject, message_text):

    message = MIMEText(message_text)
    message['to'] = to
    message['from'] = sender
    message['subject'] = subject

    return {'raw': base64.urlsafe_b64encode(message.as_string().encode()).decode()}

def send_message(service, user_id, message):

    message = (service.users().messages().send(userId="me", body=message).execute())
    print('Message Id: %s' % message['id'])
    return message

def send_email(orders):
    SCOPES = 'https://mail.google.com/'
    store = file.Storage('token.json')
    creds = store.get()
    if not creds or creds.invalid:
        flow = client.flow_from_clientsecrets('credentials.json', SCOPES)
        creds = tools.run_flow(flow, store)
    service = discovery.build('gmail','v1',http=creds.authorize(Http()))

    message_text = orders[0]

    created_message = create_message('malikhasan@google.com','malikhasan@google.com','subject', message_text)
    send_message(service, 'from', created_message)
send_email(['Hey there man'])
# Out:
# Message Id: 165cbf887b6ef02a

# %% [markdown]
# # GOOGLE SHEETS DEAL REG IMPORT

# %%
import datetime as dt

# %%
mon = 'July'

# %%
bookings.columns

# %%
bookings.columns

# %%
month_found

# %%
mon= mon.replace('present', currentMonth)
mon=mon.replace('current', currentMonth)
print('Stem: Here are the rebates for {}'.format(mon))
speak("Here are the Deal Reg rebates for {}".format(mon))
you = gs.open('Example') 
youzz = you[6]
youzz.get_as_df(has_header=True, index_colum=None, start=None, end=None, numerize=True, empty_value="")
bookings =youzz.get_as_df(has_header=True, index_colum=None, start=None, end=None, numerize=True, empty_value="")  
bookings['booking_date'] = pd.to_datetime(bookings['booking_date'])
bookings['bookingmonth'] = bookings['booking_date'].dt.strftime('%B')
bookings = bookings.loc[(bookings['Running_Total'] >= 18000)].copy()
monthly_rebates = bookings.loc[bookings['bookingmonth'].isin(month_found)].copy()
#monthly_rebates.loc[:,'Rebates']= monthly_rebates.loc[:, 'running_total'].apply(lambda x: x*.06 if x>=18000 else 0)
rebates_count = monthly_rebates['Name'].nunique()
print("there were {} rebates for the month of {}.".format(rebates_count, mon))
speak("there were {} rebates for the month of {}.".format(rebates_count, mon))
column_names = ['Name','partner','booking_date', 'Rebate']
monthly_rebates =monthly_rebates.loc[:, column_names]
display(monthly_rebates)

# %%
#open the google spreadsheet (where 'PY to Gsheet Test' is the name of my sheet)
mm = gs.create("new sheet")
#select the new sheet 


#update the first sheet with sku_bookings, starting at cell B2. 

mm.set_dataframe(sku_bookings, start='A1' ,copy_index=False, copy_head= True, fit=True)

# %%
# Open spreadsheet and then workseet
sh = gs.open('Example')
wks = sh.sheet1

sh.share("malikhasan@google.com")

# %%
https://www.cloudconnect.goog/docs/DOC-24336

# %%
from hyperlink import URL

# %%
url = URL.from_text(u'http://github.com/python-hyper/hyperlink?utm_source=README')
utm_source = url.get(u'utm_source')
better_url = url.replace(scheme=u'https', port=443)
org_url = better_url.click(u'.')

# %%
org_url

# %%
import bleach

str = 'www.google.com or https://gohugo.io/hosting-and-deployment/hosting-on-github/'
html = bleach.linkify(str)
print(html)

# %%
html

# %%
from bs4 import BeautifulSoup
import requests
import urllib.request

response = ['deal+reg']
#types_of_doctor = ['dermatologist', 'gynecologist', 'paediatric-surgeon', 'cardiologist', 'diabetologists', 'eye-specialist']
def search():
    for query in response:
        # Constracting http query
        url = 'https://www.cloudconnect.goog/search.jspa?q=' + query
        r = requests.get(url)
        soup = BeautifulSoup(r.content, 'html.parser')
        program_info = soup.findAll('a', {"class" : "NormalText"})
        for prog in program_info:
            print(prog.text)
      
search()

# %%
import requests
import urllib.request
import urllib.error
from urllib.parse import urlencode

from bs4 import BeautifulSoup

url = "https://www.cloudconnect.goog/search.jspa?q="
data = urlencode({'q': 'deal reg'})
results = requests.post(url, data)
soup = BeautifulSoup(results.content, 'html.parser').encode("ascii", "ignore")
print(soup)

# %%
https://www.cloudconnect.goog/docs/DOC-24336

# %%
import urllib.request
import urllib.error
page = urlopen("https://www.cloudconnect.goog/docs/DOC-24336")
contents = page.read()

# %%
var=input('Please type in the Program: ')
var= var.lower()
if var=='fast track':
    webbrowser.open('https://www.cloudconnect.goog/docs/DOC-19904')
if var =='deal reg':
    webbrowser.open('https://www.cloudconnect.goog/docs/DOC-24336')
if var == 'psf' or 'partner services fund':
    webbrowser.open('https://www.cloudconnect.goog/docs/DOC-19870')
if var in ('sandbox', 'sandbox credits'):
    webbrowser.open('https://www.cloudconnect.goog/docs/DOC-16822')
else:
    webbrowser.open('https://www.cloudconnect.goog/search.jspa?q={}'.format(var))
